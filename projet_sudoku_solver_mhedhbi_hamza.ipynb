# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/digits/Digits/7/img008-00675.png
# /kaggle/input/digits/Digits/7/img008-00327.png
# /kaggle/input/digits/Digits/7/img008-00721.png
# /kaggle/input/digits/Digits/7/img008-00137.png
# /kaggle/input/digits/Digits/7/img008-00450.png
# /kaggle/input/digits/Digits/7/img008-00002.png
# /kaggle/input/digits/Digits/7/img008-00428.png
# /kaggle/input/digits/Digits/7/img008-00776.png
# /kaggle/input/digits/Digits/7/img008-00896.png
# /kaggle/input/digits/Digits/7/img008-00188.png
# /kaggle/input/digits/Digits/7/img008-00021.png
# /kaggle/input/digits/Digits/7/img008-00080.png
# /kaggle/input/digits/Digits/7/img008-00382.png
# /kaggle/input/digits/Digits/7/img008-00459.png
# /kaggle/input/digits/Digits/7/img008-00738.png
# /kaggle/input/digits/Digits/7/img008-00887.png
# /kaggle/input/digits/Digits/7/img008-00095.png
# /kaggle/input/digits/Digits/7/img008-00476.png
# /kaggle/input/digits/Digits/7/img008-00930.png
# /kaggle/input/digits/Digits/7/img008-00036.png
# /kaggle/input/digits/Digits/7/img008-00071.png
# /kaggle/input/digits/Digits/7/img008-00988.png
# /kaggle/input/digits/Digits/7/img008-00552.png
# /kaggle/input/digits/Digits/7/img008-00279.png
# /kaggle/input/digits/Digits/7/img008-00032.png
# /kaggle/input/digits/Digits/7/img008-00033.png
# /kaggle/input/digits/Digits/7/img008-00696.png
# /kaggle/input/digits/Digits/7/img008-00982.png
# /kaggle/input/digits/Digits/7/img008-00797.png
# /kaggle/input/digits/Digits/7/img008-00417.png
# /kaggle/input/digits/Digits/7/img008-00253.png
# /kaggle/input/digits/Digits/7/img008-00443.png
# /kaggle/input/digits/Digits/7/img008-00195.png
# /kaggle/input/digits/Digits/7/img008-00903.png
# /kaggle/input/digits/Digits/7/img008-00180.png
# /kaggle/input/digits/Digits/7/img008-00941.png
# /kaggle/input/digits/Digits/7/img008-00927.png
# /kaggle/input/digits/Digits/7/img008-00888.png
# /kaggle/input/digits/Digits/7/img008-00269.png
# /kaggle/input/digits/Digits/7/img008-00523.png
# /kaggle/input/digits/Digits/7/img008-00004.png
# /kaggle/input/digits/Digits/7/img008-00588.png
# /kaggle/input/digits/Digits/7/img008-00313.png
# /kaggle/input/digits/Digits/7/img008-00678.png
# /kaggle/input/digits/Digits/7/img008-00039.png
# /kaggle/input/digits/Digits/7/img008-00247.png
# /kaggle/input/digits/Digits/7/img008-00538.png
# /kaggle/input/digits/Digits/7/img008-00659.png
# /kaggle/input/digits/Digits/7/img008-00864.png
# /kaggle/input/digits/Digits/7/img008-00624.png
# /kaggle/input/digits/Digits/7/img008-00713.png
# /kaggle/input/digits/Digits/7/img008-00750.png
# /kaggle/input/digits/Digits/7/img008-00599.png
# /kaggle/input/digits/Digits/7/img008-00979.png
# /kaggle/input/digits/Digits/7/img008-00098.png
# /kaggle/input/digits/Digits/7/img008-00948.png
# /kaggle/input/digits/Digits/7/img008-00683.png
# /kaggle/input/digits/Digits/7/img008-00176.png
# /kaggle/input/digits/Digits/7/img008-00045.png
# /kaggle/input/digits/Digits/7/img008-00120.png
# /kaggle/input/digits/Digits/7/img008-00581.png
# /kaggle/input/digits/Digits/7/img008-00118.png
# /kaggle/input/digits/Digits/7/img008-00056.png
# /kaggle/input/digits/Digits/7/img008-00849.png
# /kaggle/input/digits/Digits/7/img008-00852.png
# /kaggle/input/digits/Digits/7/img008-00978.png
# /kaggle/input/digits/Digits/7/img008-00712.png
# /kaggle/input/digits/Digits/7/img008-00554.png
# /kaggle/input/digits/Digits/7/img008-00833.png
# /kaggle/input/digits/Digits/7/img008-00654.png
# /kaggle/input/digits/Digits/7/img008-00146.png
# /kaggle/input/digits/Digits/7/img008-00171.png
# /kaggle/input/digits/Digits/7/img008-01000.png
# /kaggle/input/digits/Digits/7/img008-00810.png
# /kaggle/input/digits/Digits/7/img008-00655.png
# /kaggle/input/digits/Digits/7/img008-00560.png
# /kaggle/input/digits/Digits/7/img008-00487.png
# /kaggle/input/digits/Digits/7/img008-00490.png
# /kaggle/input/digits/Digits/7/img008-00739.png
# /kaggle/input/digits/Digits/7/img008-00612.png
# /kaggle/input/digits/Digits/7/img008-00997.png
# /kaggle/input/digits/Digits/7/img008-00892.png
# /kaggle/input/digits/Digits/7/img008-00186.png
# /kaggle/input/digits/Digits/7/img008-00251.png
# /kaggle/input/digits/Digits/7/img008-00766.png
# /kaggle/input/digits/Digits/7/img008-00541.png
# /kaggle/input/digits/Digits/7/img008-00051.png
# /kaggle/input/digits/Digits/7/img008-00326.png
# /kaggle/input/digits/Digits/7/img008-00695.png
# /kaggle/input/digits/Digits/7/img008-01003.png
# /kaggle/input/digits/Digits/7/img008-00371.png
# /kaggle/input/digits/Digits/7/img008-00001.png
# /kaggle/input/digits/Digits/7/img008-00540.png
# /kaggle/input/digits/Digits/7/img008-00017.png
# /kaggle/input/digits/Digits/7/img008-00026.png
# /kaggle/input/digits/Digits/7/img008-00778.png
# /kaggle/input/digits/Digits/7/img008-00881.png
# /kaggle/input/digits/Digits/7/img008-00502.png
# /kaggle/input/digits/Digits/7/img008-00479.png
# /kaggle/input/digits/Digits/7/img008-00875.png
# /kaggle/input/digits/Digits/7/img008-00775.png
# /kaggle/input/digits/Digits/7/img008-00994.png
# /kaggle/input/digits/Digits/7/img008-00153.png
# /kaggle/input/digits/Digits/7/img008-00944.png
# /kaggle/input/digits/Digits/7/img008-00556.png
# /kaggle/input/digits/Digits/7/img008-00526.png
# /kaggle/input/digits/Digits/7/img008-00649.png
# /kaggle/input/digits/Digits/7/img008-00673.png
# /kaggle/input/digits/Digits/7/img008-00543.png
# /kaggle/input/digits/Digits/7/img008-00246.png
# /kaggle/input/digits/Digits/7/img008-00506.png
# /kaggle/input/digits/Digits/7/img008-00282.png
# /kaggle/input/digits/Digits/7/img008-00474.png
# /kaggle/input/digits/Digits/7/img008-00890.png
# /kaggle/input/digits/Digits/7/img008-00131.png
# /kaggle/input/digits/Digits/7/img008-00049.png
# /kaggle/input/digits/Digits/7/img008-00735.png
# /kaggle/input/digits/Digits/7/img008-00232.png
# /kaggle/input/digits/Digits/7/img008-00594.png
# /kaggle/input/digits/Digits/7/img008-00286.png
# /kaggle/input/digits/Digits/7/img008-00200.png
# /kaggle/input/digits/Digits/7/img008-00168.png
# /kaggle/input/digits/Digits/7/img008-00166.png
# /kaggle/input/digits/Digits/7/img008-00462.png
# /kaggle/input/digits/Digits/7/img008-00062.png
# /kaggle/input/digits/Digits/7/img008-00708.png
# /kaggle/input/digits/Digits/7/img008-00329.png
# /kaggle/input/digits/Digits/7/img008-00396.png
# /kaggle/input/digits/Digits/7/img008-00593.png
# /kaggle/input/digits/Digits/7/img008-00527.png
# /kaggle/input/digits/Digits/7/img008-00661.png
# /kaggle/input/digits/Digits/7/img008-00561.png
# /kaggle/input/digits/Digits/7/img008-00597.png
# /kaggle/input/digits/Digits/7/img008-00228.png
# /kaggle/input/digits/Digits/7/img008-00354.png
# /kaggle/input/digits/Digits/7/img008-00692.png
# /kaggle/input/digits/Digits/7/img008-00210.png
# /kaggle/input/digits/Digits/7/img008-00509.png
# /kaggle/input/digits/Digits/7/img008-00762.png
# /kaggle/input/digits/Digits/7/img008-00452.png
# /kaggle/input/digits/Digits/7/img008-00774.png
# /kaggle/input/digits/Digits/7/img008-00992.png
# /kaggle/input/digits/Digits/7/img008-00889.png
# /kaggle/input/digits/Digits/7/img008-00872.png
# /kaggle/input/digits/Digits/7/img008-00700.png
# /kaggle/input/digits/Digits/7/img008-00909.png
# /kaggle/input/digits/Digits/7/img008-00373.png
# /kaggle/input/digits/Digits/7/img008-00530.png
# /kaggle/input/digits/Digits/7/img008-00010.png
# /kaggle/input/digits/Digits/7/img008-00522.png
# /kaggle/input/digits/Digits/7/img008-00779.png
# /kaggle/input/digits/Digits/7/img008-00339.png
# /kaggle/input/digits/Digits/7/img008-00183.png
# /kaggle/input/digits/Digits/7/img008-00411.png
# /kaggle/input/digits/Digits/7/img008-00619.png
# /kaggle/input/digits/Digits/7/img008-00018.png
# /kaggle/input/digits/Digits/7/img008-00415.png
# /kaggle/input/digits/Digits/7/img008-00250.png
# /kaggle/input/digits/Digits/7/img008-00344.png
# /kaggle/input/digits/Digits/7/img008-00318.png
# /kaggle/input/digits/Digits/7/img008-00234.png
# /kaggle/input/digits/Digits/7/img008-00901.png
# /kaggle/input/digits/Digits/7/img008-00455.png
# /kaggle/input/digits/Digits/7/img008-00703.png
# /kaggle/input/digits/Digits/7/img008-00677.png
# /kaggle/input/digits/Digits/7/img008-00283.png
# /kaggle/input/digits/Digits/7/img008-00497.png
# /kaggle/input/digits/Digits/7/img008-00728.png
# /kaggle/input/digits/Digits/7/img008-00470.png
# /kaggle/input/digits/Digits/7/img008-00499.png
# /kaggle/input/digits/Digits/7/img008-00919.png
# /kaggle/input/digits/Digits/7/img008-00083.png
# /kaggle/input/digits/Digits/7/img008-00698.png
# /kaggle/input/digits/Digits/7/img008-00160.png
# /kaggle/input/digits/Digits/7/img008-00973.png
# /kaggle/input/digits/Digits/7/img008-00159.png
# /kaggle/input/digits/Digits/7/img008-00257.png
# /kaggle/input/digits/Digits/7/img008-00054.png
# /kaggle/input/digits/Digits/7/img008-00871.png
# /kaggle/input/digits/Digits/7/img008-00319.png
# /kaggle/input/digits/Digits/7/img008-00644.png
# /kaggle/input/digits/Digits/7/img008-00304.png
# /kaggle/input/digits/Digits/7/img008-00719.png
# /kaggle/input/digits/Digits/7/img008-00055.png
# /kaggle/input/digits/Digits/7/img008-00837.png
# /kaggle/input/digits/Digits/7/img008-00401.png
# /kaggle/input/digits/Digits/7/img008-00894.png
# /kaggle/input/digits/Digits/7/img008-00024.png
# /kaggle/input/digits/Digits/7/img008-00570.png
# /kaggle/input/digits/Digits/7/img008-00843.png
# /kaggle/input/digits/Digits/7/img008-00042.png
# /kaggle/input/digits/Digits/7/img008-00221.png
# /kaggle/input/digits/Digits/7/img008-00501.png
# /kaggle/input/digits/Digits/7/img008-00921.png
# /kaggle/input/digits/Digits/7/img008-00572.png
# /kaggle/input/digits/Digits/7/img008-00958.png
# /kaggle/input/digits/Digits/7/img008-00084.png
# /kaggle/input/digits/Digits/7/img008-00851.png
# /kaggle/input/digits/Digits/7/img008-00900.png
# /kaggle/input/digits/Digits/7/img008-00848.png
# /kaggle/input/digits/Digits/7/img008-00792.png
# /kaggle/input/digits/Digits/7/img008-00932.png
# /kaggle/input/digits/Digits/7/img008-00308.png
# /kaggle/input/digits/Digits/7/img008-00598.png
# /kaggle/input/digits/Digits/7/img008-00812.png
# /kaggle/input/digits/Digits/7/img008-00408.png
# /kaggle/input/digits/Digits/7/img008-00015.png
# /kaggle/input/digits/Digits/7/img008-00961.png
# /kaggle/input/digits/Digits/7/img008-00077.png
# /kaggle/input/digits/Digits/7/img008-00711.png
# /kaggle/input/digits/Digits/7/img008-00167.png
# /kaggle/input/digits/Digits/7/img008-00577.png
# /kaggle/input/digits/Digits/7/img008-00212.png
# /kaggle/input/digits/Digits/7/img008-00867.png
# /kaggle/input/digits/Digits/7/img008-00358.png
# /kaggle/input/digits/Digits/7/img008-00041.png
# /kaggle/input/digits/Digits/7/img008-00158.png
# /kaggle/input/digits/Digits/7/img008-00605.png
# /kaggle/input/digits/Digits/7/img008-00201.png
# /kaggle/input/digits/Digits/7/img008-00149.png
# /kaggle/input/digits/Digits/7/img008-00718.png
# /kaggle/input/digits/Digits/7/img008-00376.png
# /kaggle/input/digits/Digits/7/img008-00110.png
# /kaggle/input/digits/Digits/7/img008-00053.png
# /kaggle/input/digits/Digits/7/img008-00285.png
# /kaggle/input/digits/Digits/7/img008-00911.png
# /kaggle/input/digits/Digits/7/img008-00305.png
# /kaggle/input/digits/Digits/7/img008-00714.png
# /kaggle/input/digits/Digits/7/img008-00466.png
# /kaggle/input/digits/Digits/7/img008-00367.png
# /kaggle/input/digits/Digits/7/img008-00389.png
# /kaggle/input/digits/Digits/7/img008-00431.png
# /kaggle/input/digits/Digits/7/img008-00914.png
# /kaggle/input/digits/Digits/7/img008-00920.png
# /kaggle/input/digits/Digits/7/img008-00937.png
# /kaggle/input/digits/Digits/7/img008-00954.png
# /kaggle/input/digits/Digits/7/img008-00423.png
# /kaggle/input/digits/Digits/7/img008-00471.png
# /kaggle/input/digits/Digits/7/img008-00582.png
# /kaggle/input/digits/Digits/7/img008-00448.png
# /kaggle/input/digits/Digits/7/img008-00637.png
# /kaggle/input/digits/Digits/7/img008-00343.png
# /kaggle/input/digits/Digits/7/img008-00127.png
# /kaggle/input/digits/Digits/7/img008-00208.png
# /kaggle/input/digits/Digits/7/img008-00595.png
# /kaggle/input/digits/Digits/7/img008-00549.png
# /kaggle/input/digits/Digits/7/img008-00223.png
# /kaggle/input/digits/Digits/7/img008-00625.png
# /kaggle/input/digits/Digits/7/img008-00363.png
# /kaggle/input/digits/Digits/7/img008-00322.png
# /kaggle/input/digits/Digits/7/img008-00807.png
# /kaggle/input/digits/Digits/7/img008-00566.png
# /kaggle/input/digits/Digits/7/img008-00508.png
# /kaggle/input/digits/Digits/7/img008-00806.png
# /kaggle/input/digits/Digits/7/img008-00639.png
# /kaggle/input/digits/Digits/7/img008-00275.png
# /kaggle/input/digits/Digits/7/img008-00821.png
# /kaggle/input/digits/Digits/7/img008-00855.png
# /kaggle/input/digits/Digits/7/img008-00395.png
# /kaggle/input/digits/Digits/7/img008-00641.png
# /kaggle/input/digits/Digits/7/img008-00604.png
# /kaggle/input/digits/Digits/7/img008-01004.png
# /kaggle/input/digits/Digits/7/img008-00478.png
# /kaggle/input/digits/Digits/7/img008-00996.png
# /kaggle/input/digits/Digits/7/img008-00842.png
# /kaggle/input/digits/Digits/7/img008-00394.png
# /kaggle/input/digits/Digits/7/img008-00193.png
# /kaggle/input/digits/Digits/7/img008-00088.png
# /kaggle/input/digits/Digits/7/img008-00870.png
# /kaggle/input/digits/Digits/7/img008-00743.png
# /kaggle/input/digits/Digits/7/img008-00029.png
# /kaggle/input/digits/Digits/7/img008-00320.png
# /kaggle/input/digits/Digits/7/img008-00177.png
# /kaggle/input/digits/Digits/7/img008-00421.png
# /kaggle/input/digits/Digits/7/img008-00521.png
# /kaggle/input/digits/Digits/7/img008-00112.png
# /kaggle/input/digits/Digits/7/img008-00064.png
# /kaggle/input/digits/Digits/7/img008-00663.png
# /kaggle/input/digits/Digits/7/img008-00853.png
# /kaggle/input/digits/Digits/7/img008-00537.png
# /kaggle/input/digits/Digits/7/img008-00436.png
# /kaggle/input/digits/Digits/7/img008-00480.png
# /kaggle/input/digits/Digits/7/img008-00141.png
# /kaggle/input/digits/Digits/7/img008-00081.png
# /kaggle/input/digits/Digits/7/img008-00608.png
# /kaggle/input/digits/Digits/7/img008-00773.png
# /kaggle/input/digits/Digits/7/img008-00397.png
# /kaggle/input/digits/Digits/7/img008-00658.png
# /kaggle/input/digits/Digits/7/img008-00981.png
# /kaggle/input/digits/Digits/7/img008-00303.png
# /kaggle/input/digits/Digits/7/img008-00027.png
# /kaggle/input/digits/Digits/7/img008-00742.png
# /kaggle/input/digits/Digits/7/img008-00238.png
# /kaggle/input/digits/Digits/7/img008-00008.png
# /kaggle/input/digits/Digits/7/img008-00772.png
# /kaggle/input/digits/Digits/7/img008-00951.png
# /kaggle/input/digits/Digits/7/img008-00525.png
# /kaggle/input/digits/Digits/7/img008-00147.png
# /kaggle/input/digits/Digits/7/img008-00650.png
# /kaggle/input/digits/Digits/7/img008-00090.png
# /kaggle/input/digits/Digits/7/img008-00769.png
# /kaggle/input/digits/Digits/7/img008-00419.png
# /kaggle/input/digits/Digits/7/img008-00859.png
# /kaggle/input/digits/Digits/7/img008-00801.png
# /kaggle/input/digits/Digits/7/img008-00445.png
# /kaggle/input/digits/Digits/7/img008-00047.png
# /kaggle/input/digits/Digits/7/img008-00063.png
# /kaggle/input/digits/Digits/7/img008-00387.png
# /kaggle/input/digits/Digits/7/img008-00974.png
# /kaggle/input/digits/Digits/7/img008-00437.png
# /kaggle/input/digits/Digits/7/img008-01016.png
# /kaggle/input/digits/Digits/7/img008-00012.png
# /kaggle/input/digits/Digits/7/img008-00959.png
# /kaggle/input/digits/Digits/7/img008-00248.png
# /kaggle/input/digits/Digits/7/img008-00999.png
# /kaggle/input/digits/Digits/7/img008-00264.png
# /kaggle/input/digits/Digits/7/img008-00547.png
# /kaggle/input/digits/Digits/7/img008-00515.png
# /kaggle/input/digits/Digits/7/img008-00306.png
# /kaggle/input/digits/Digits/7/img008-00219.png
# /kaggle/input/digits/Digits/7/img008-00365.png
# /kaggle/input/digits/Digits/7/img008-00052.png
# /kaggle/input/digits/Digits/7/img008-00425.png
# /kaggle/input/digits/Digits/7/img008-00184.png
# /kaggle/input/digits/Digits/7/img008-00925.png
# /kaggle/input/digits/Digits/7/img008-00587.png
# /kaggle/input/digits/Digits/7/img008-00328.png
# /kaggle/input/digits/Digits/7/img008-00809.png
# /kaggle/input/digits/Digits/7/img008-00529.png
# /kaggle/input/digits/Digits/7/img008-00299.png
# /kaggle/input/digits/Digits/7/img008-00519.png
# /kaggle/input/digits/Digits/7/img008-00138.png
# /kaggle/input/digits/Digits/7/img008-00585.png
# /kaggle/input/digits/Digits/7/img008-00814.png
# /kaggle/input/digits/Digits/7/img008-00154.png
# /kaggle/input/digits/Digits/7/img008-00803.png
# /kaggle/input/digits/Digits/7/img008-00375.png
# /kaggle/input/digits/Digits/7/img008-00316.png
# /kaggle/input/digits/Digits/7/img008-00815.png
# /kaggle/input/digits/Digits/7/img008-00674.png
# /kaggle/input/digits/Digits/7/img008-00877.png
# /kaggle/input/digits/Digits/7/img008-00073.png
# /kaggle/input/digits/Digits/7/img008-00170.png
# /kaggle/input/digits/Digits/7/img008-00379.png
# /kaggle/input/digits/Digits/7/img008-00569.png
# /kaggle/input/digits/Digits/7/img008-00770.png
# /kaggle/input/digits/Digits/7/img008-00518.png
# /kaggle/input/digits/Digits/7/img008-00768.png
# /kaggle/input/digits/Digits/7/img008-00929.png
# /kaggle/input/digits/Digits/7/img008-00616.png
# /kaggle/input/digits/Digits/7/img008-00434.png
# /kaggle/input/digits/Digits/7/img008-01002.png
# /kaggle/input/digits/Digits/7/img008-00155.png
# /kaggle/input/digits/Digits/7/img008-00563.png
# /kaggle/input/digits/Digits/7/img008-00603.png
# /kaggle/input/digits/Digits/7/img008-00196.png
# /kaggle/input/digits/Digits/7/img008-00688.png
# /kaggle/input/digits/Digits/7/img008-00765.png
# /kaggle/input/digits/Digits/7/img008-00301.png
# /kaggle/input/digits/Digits/7/img008-00215.png
# /kaggle/input/digits/Digits/7/img008-00578.png
# /kaggle/input/digits/Digits/7/img008-00983.png
# /kaggle/input/digits/Digits/7/img008-00917.png
# /kaggle/input/digits/Digits/7/img008-00059.png
# /kaggle/input/digits/Digits/7/img008-00609.png
# /kaggle/input/digits/Digits/7/img008-00189.png
# /kaggle/input/digits/Digits/7/img008-00475.png
# /kaggle/input/digits/Digits/7/img008-00078.png
# /kaggle/input/digits/Digits/7/img008-00260.png
# /kaggle/input/digits/Digits/7/img008-00589.png
# /kaggle/input/digits/Digits/7/img008-00660.png
# /kaggle/input/digits/Digits/7/img008-00970.png
# /kaggle/input/digits/Digits/7/img008-00105.png
# /kaggle/input/digits/Digits/7/img008-00950.png
# /kaggle/input/digits/Digits/7/img008-00364.png
# /kaggle/input/digits/Digits/7/img008-00730.png
# /kaggle/input/digits/Digits/7/img008-00690.png
# /kaggle/input/digits/Digits/7/img008-00962.png
# /kaggle/input/digits/Digits/7/img008-00192.png
# /kaggle/input/digits/Digits/7/img008-00580.png
# /kaggle/input/digits/Digits/7/img008-00648.png
# /kaggle/input/digits/Digits/7/img008-00406.png
# /kaggle/input/digits/Digits/7/img008-00464.png
# /kaggle/input/digits/Digits/7/img008-00705.png
# /kaggle/input/digits/Digits/7/img008-00850.png
# /kaggle/input/digits/Digits/7/img008-00618.png
# /kaggle/input/digits/Digits/7/img008-00874.png
# /kaggle/input/digits/Digits/7/img008-00284.png
# /kaggle/input/digits/Digits/7/img008-00736.png
# /kaggle/input/digits/Digits/7/img008-00432.png
# /kaggle/input/digits/Digits/7/img008-00498.png
# /kaggle/input/digits/Digits/7/img008-00190.png
# /kaggle/input/digits/Digits/7/img008-00122.png
# /kaggle/input/digits/Digits/7/img008-00410.png
# /kaggle/input/digits/Digits/7/img008-00104.png
# /kaggle/input/digits/Digits/7/img008-00405.png
# /kaggle/input/digits/Digits/7/img008-00816.png
# /kaggle/input/digits/Digits/7/img008-00386.png
# /kaggle/input/digits/Digits/7/img008-00699.png
# /kaggle/input/digits/Digits/7/img008-00414.png
# /kaggle/input/digits/Digits/7/img008-00865.png
# /kaggle/input/digits/Digits/7/img008-00891.png
# /kaggle/input/digits/Digits/7/img008-00884.png
# /kaggle/input/digits/Digits/7/img008-00311.png
# /kaggle/input/digits/Digits/7/img008-00866.png
# /kaggle/input/digits/Digits/7/img008-00790.png
# /kaggle/input/digits/Digits/7/img008-00574.png
# /kaggle/input/digits/Digits/7/img008-00749.png
# /kaggle/input/digits/Digits/7/img008-01012.png
# /kaggle/input/digits/Digits/7/img008-00952.png
# /kaggle/input/digits/Digits/7/img008-00065.png
# /kaggle/input/digits/Digits/7/img008-00366.png
# /kaggle/input/digits/Digits/7/img008-00802.png
# /kaggle/input/digits/Digits/7/img008-00905.png
# /kaggle/input/digits/Digits/7/img008-00945.png
# /kaggle/input/digits/Digits/7/img008-00321.png
# /kaggle/input/digits/Digits/7/img008-00456.png
# /kaggle/input/digits/Digits/7/img008-00341.png
# /kaggle/input/digits/Digits/7/img008-00966.png
# /kaggle/input/digits/Digits/7/img008-00280.png
# /kaggle/input/digits/Digits/7/img008-00733.png
# /kaggle/input/digits/Digits/7/img008-00292.png
# /kaggle/input/digits/Digits/7/img008-00271.png
# /kaggle/input/digits/Digits/7/img008-00211.png
# /kaggle/input/digits/Digits/7/img008-00484.png
# /kaggle/input/digits/Digits/7/img008-00214.png
# /kaggle/input/digits/Digits/7/img008-00717.png
# /kaggle/input/digits/Digits/7/img008-00817.png
# /kaggle/input/digits/Digits/7/img008-00645.png
# /kaggle/input/digits/Digits/7/img008-00924.png
# /kaggle/input/digits/Digits/7/img008-00780.png
# /kaggle/input/digits/Digits/7/img008-00360.png
# /kaggle/input/digits/Digits/7/img008-01008.png
# /kaggle/input/digits/Digits/7/img008-00061.png
# /kaggle/input/digits/Digits/7/img008-00463.png
# /kaggle/input/digits/Digits/7/img008-00181.png
# /kaggle/input/digits/Digits/7/img008-00231.png
# /kaggle/input/digits/Digits/7/img008-00536.png
# /kaggle/input/digits/Digits/7/img008-00761.png
# /kaggle/input/digits/Digits/7/img008-00413.png
# /kaggle/input/digits/Digits/7/img008-00737.png
# /kaggle/input/digits/Digits/7/img008-00197.png
# /kaggle/input/digits/Digits/7/img008-00224.png
# /kaggle/input/digits/Digits/7/img008-00143.png
# /kaggle/input/digits/Digits/7/img008-00826.png
# /kaggle/input/digits/Digits/7/img008-00350.png
# /kaggle/input/digits/Digits/7/img008-00960.png
# /kaggle/input/digits/Digits/7/img008-00818.png
# /kaggle/input/digits/Digits/7/img008-00357.png
# /kaggle/input/digits/Digits/7/img008-00037.png
# /kaggle/input/digits/Digits/7/img008-00129.png
# /kaggle/input/digits/Digits/7/img008-00879.png
# /kaggle/input/digits/Digits/7/img008-00031.png
# /kaggle/input/digits/Digits/7/img008-00302.png
# /kaggle/input/digits/Digits/7/img008-00876.png
# /kaggle/input/digits/Digits/7/img008-00752.png
# /kaggle/input/digits/Digits/7/img008-00348.png
# /kaggle/input/digits/Digits/7/img008-00956.png
# /kaggle/input/digits/Digits/7/img008-00265.png
# /kaggle/input/digits/Digits/7/img008-00107.png
# /kaggle/input/digits/Digits/7/img008-00040.png
# /kaggle/input/digits/Digits/7/img008-00827.png
# /kaggle/input/digits/Digits/7/img008-00794.png
# /kaggle/input/digits/Digits/7/img008-00986.png
# /kaggle/input/digits/Digits/7/img008-00638.png
# /kaggle/input/digits/Digits/7/img008-00783.png
# /kaggle/input/digits/Digits/7/img008-00481.png
# /kaggle/input/digits/Digits/7/img008-00255.png
# /kaggle/input/digits/Digits/7/img008-00706.png
# /kaggle/input/digits/Digits/7/img008-00926.png
# /kaggle/input/digits/Digits/7/img008-00551.png
# /kaggle/input/digits/Digits/7/img008-00697.png
# /kaggle/input/digits/Digits/7/img008-00857.png
# /kaggle/input/digits/Digits/7/img008-00512.png
# /kaggle/input/digits/Digits/7/img008-00672.png
# /kaggle/input/digits/Digits/7/img008-00854.png
# /kaggle/input/digits/Digits/7/img008-00975.png
# /kaggle/input/digits/Digits/7/img008-00646.png
# /kaggle/input/digits/Digits/7/img008-00038.png
# /kaggle/input/digits/Digits/7/img008-00985.png
# /kaggle/input/digits/Digits/7/img008-00259.png
# /kaggle/input/digits/Digits/7/img008-01010.png
# /kaggle/input/digits/Digits/7/img008-00847.png
# /kaggle/input/digits/Digits/7/img008-00330.png
# /kaggle/input/digits/Digits/7/img008-00488.png
# /kaggle/input/digits/Digits/7/img008-00844.png
# /kaggle/input/digits/Digits/7/img008-01005.png
# /kaggle/input/digits/Digits/7/img008-00416.png
# /kaggle/input/digits/Digits/7/img008-00873.png
# /kaggle/input/digits/Digits/7/img008-00006.png
# /kaggle/input/digits/Digits/7/img008-00333.png
# /kaggle/input/digits/Digits/7/img008-00381.png
# /kaggle/input/digits/Digits/7/img008-00412.png
# /kaggle/input/digits/Digits/7/img008-00291.png
# /kaggle/input/digits/Digits/7/img008-00035.png
# /kaggle/input/digits/Digits/7/img008-00701.png
# /kaggle/input/digits/Digits/7/img008-00787.png
# /kaggle/input/digits/Digits/7/img008-00164.png
# /kaggle/input/digits/Digits/7/img008-00014.png
# /kaggle/input/digits/Digits/7/img008-00325.png
# /kaggle/input/digits/Digits/7/img008-00388.png
# /kaggle/input/digits/Digits/7/img008-00342.png
# /kaggle/input/digits/Digits/7/img008-01009.png
# /kaggle/input/digits/Digits/7/img008-00856.png
# /kaggle/input/digits/Digits/7/img008-00722.png
# /kaggle/input/digits/Digits/7/img008-00267.png
# /kaggle/input/digits/Digits/7/img008-00715.png
# /kaggle/input/digits/Digits/7/img008-00989.png
# /kaggle/input/digits/Digits/7/img008-00592.png
# /kaggle/input/digits/Digits/7/img008-00784.png
# /kaggle/input/digits/Digits/7/img008-00825.png
# /kaggle/input/digits/Digits/7/img008-00114.png
# /kaggle/input/digits/Digits/7/img008-00669.png
# /kaggle/input/digits/Digits/7/img008-00912.png
# /kaggle/input/digits/Digits/7/img008-00869.png
# /kaggle/input/digits/Digits/7/img008-00023.png
# /kaggle/input/digits/Digits/7/img008-00626.png
# /kaggle/input/digits/Digits/7/img008-00070.png
# /kaggle/input/digits/Digits/7/img008-00169.png
# /kaggle/input/digits/Digits/7/img008-00709.png
# /kaggle/input/digits/Digits/7/img008-00898.png
# /kaggle/input/digits/Digits/7/img008-00651.png
# /kaggle/input/digits/Digits/7/img008-00611.png
# /kaggle/input/digits/Digits/7/img008-00707.png
# /kaggle/input/digits/Digits/7/img008-00923.png
# /kaggle/input/digits/Digits/7/img008-00263.png
# /kaggle/input/digits/Digits/7/img008-00548.png
# /kaggle/input/digits/Digits/7/img008-00034.png
# /kaggle/input/digits/Digits/7/img008-00294.png
# /kaggle/input/digits/Digits/7/img008-00939.png
# /kaggle/input/digits/Digits/7/img008-00868.png
# /kaggle/input/digits/Digits/7/img008-00601.png
# /kaggle/input/digits/Digits/7/img008-00472.png
# /kaggle/input/digits/Digits/7/img008-00206.png
# /kaggle/input/digits/Digits/7/img008-00058.png
# /kaggle/input/digits/Digits/7/img008-00517.png
# /kaggle/input/digits/Digits/7/img008-00746.png
# /kaggle/input/digits/Digits/7/img008-00148.png
# /kaggle/input/digits/Digits/7/img008-00369.png
# /kaggle/input/digits/Digits/7/img008-00922.png
# /kaggle/input/digits/Digits/7/img008-00990.png
# /kaggle/input/digits/Digits/7/img008-00323.png
# /kaggle/input/digits/Digits/7/img008-00976.png
# /kaggle/input/digits/Digits/7/img008-00860.png
# /kaggle/input/digits/Digits/7/img008-00398.png
# /kaggle/input/digits/Digits/7/img008-00899.png
# /kaggle/input/digits/Digits/7/img008-00377.png
# /kaggle/input/digits/Digits/7/img008-00355.png
# /kaggle/input/digits/Digits/7/img008-00116.png
# /kaggle/input/digits/Digits/7/img008-00312.png
# /kaggle/input/digits/Digits/7/img008-00505.png
# /kaggle/input/digits/Digits/7/img008-00324.png
# /kaggle/input/digits/Digits/7/img008-00755.png
# /kaggle/input/digits/Digits/7/img008-00763.png
# /kaggle/input/digits/Digits/7/img008-00607.png
# /kaggle/input/digits/Digits/7/img008-00249.png
# /kaggle/input/digits/Digits/7/img008-00317.png
# /kaggle/input/digits/Digits/7/img008-00426.png
# /kaggle/input/digits/Digits/7/img008-00740.png
# /kaggle/input/digits/Digits/7/img008-00542.png
# /kaggle/input/digits/Digits/7/img008-00620.png
# /kaggle/input/digits/Digits/7/img008-00178.png
# /kaggle/input/digits/Digits/7/img008-00977.png
# /kaggle/input/digits/Digits/7/img008-00507.png
# /kaggle/input/digits/Digits/7/img008-00576.png
# /kaggle/input/digits/Digits/7/img008-00454.png
# /kaggle/input/digits/Digits/7/img008-00254.png
# /kaggle/input/digits/Digits/7/img008-00767.png
# /kaggle/input/digits/Digits/7/img008-00465.png
# /kaggle/input/digits/Digits/7/img008-00043.png
# /kaggle/input/digits/Digits/7/img008-00468.png
# /kaggle/input/digits/Digits/7/img008-00679.png
# /kaggle/input/digits/Digits/7/img008-00885.png
# /kaggle/input/digits/Digits/7/img008-00947.png
# /kaggle/input/digits/Digits/7/img008-00702.png
# /kaggle/input/digits/Digits/7/img008-00067.png
# /kaggle/input/digits/Digits/7/img008-00496.png
# /kaggle/input/digits/Digits/7/img008-00504.png
# /kaggle/input/digits/Digits/7/img008-00723.png
# /kaggle/input/digits/Digits/7/img008-00050.png
# /kaggle/input/digits/Digits/7/img008-00957.png
# /kaggle/input/digits/Digits/7/img008-00967.png
# /kaggle/input/digits/Digits/7/img008-00533.png
# /kaggle/input/digits/Digits/7/img008-00276.png
# /kaggle/input/digits/Digits/7/img008-00789.png
# /kaggle/input/digits/Digits/7/img008-00623.png
# /kaggle/input/digits/Digits/7/img008-00361.png
# /kaggle/input/digits/Digits/7/img008-00828.png
# /kaggle/input/digits/Digits/7/img008-00136.png
# /kaggle/input/digits/Digits/7/img008-00799.png
# /kaggle/input/digits/Digits/7/img008-00094.png
# /kaggle/input/digits/Digits/7/img008-00258.png
# /kaggle/input/digits/Digits/7/img008-00092.png
# /kaggle/input/digits/Digits/7/img008-00500.png
# /kaggle/input/digits/Digits/7/img008-00227.png
# /kaggle/input/digits/Digits/7/img008-00380.png
# /kaggle/input/digits/Digits/7/img008-00528.png
# /kaggle/input/digits/Digits/7/img008-00420.png
# /kaggle/input/digits/Digits/7/img008-00684.png
# /kaggle/input/digits/Digits/7/img008-00119.png
# /kaggle/input/digits/Digits/7/img008-00963.png
# /kaggle/input/digits/Digits/7/img008-00493.png
# /kaggle/input/digits/Digits/7/img008-00486.png
# /kaggle/input/digits/Digits/7/img008-00128.png
# /kaggle/input/digits/Digits/7/img008-00584.png
# /kaggle/input/digits/Digits/7/img008-00309.png
# /kaggle/input/digits/Digits/7/img008-00300.png
# /kaggle/input/digits/Digits/7/img008-00409.png
# /kaggle/input/digits/Digits/7/img008-00123.png
# /kaggle/input/digits/Digits/7/img008-00422.png
# /kaggle/input/digits/Digits/7/img008-00392.png
# /kaggle/input/digits/Digits/7/img008-00314.png
# /kaggle/input/digits/Digits/7/img008-00467.png
# /kaggle/input/digits/Digits/7/img008-00748.png
# /kaggle/input/digits/Digits/7/img008-00785.png
# /kaggle/input/digits/Digits/7/img008-00353.png
# /kaggle/input/digits/Digits/7/img008-00461.png
# /kaggle/input/digits/Digits/7/img008-00662.png
# /kaggle/input/digits/Digits/7/img008-00754.png
# /kaggle/input/digits/Digits/7/img008-00910.png
# /kaggle/input/digits/Digits/7/img008-00390.png
# /kaggle/input/digits/Digits/7/img008-00491.png
# /kaggle/input/digits/Digits/7/img008-00964.png
# /kaggle/input/digits/Digits/7/img008-00438.png
# /kaggle/input/digits/Digits/7/img008-00469.png
# /kaggle/input/digits/Digits/7/img008-00969.png
# /kaggle/input/digits/Digits/7/img008-00125.png
# /kaggle/input/digits/Digits/7/img008-00798.png
# /kaggle/input/digits/Digits/7/img008-00336.png
# /kaggle/input/digits/Digits/7/img008-00368.png
# /kaggle/input/digits/Digits/7/img008-00298.png
# /kaggle/input/digits/Digits/7/img008-00545.png
# /kaggle/input/digits/Digits/7/img008-00460.png
# /kaggle/input/digits/Digits/7/img008-00838.png
# /kaggle/input/digits/Digits/7/img008-00005.png
# /kaggle/input/digits/Digits/7/img008-00557.png
# /kaggle/input/digits/Digits/7/img008-00332.png
# /kaggle/input/digits/Digits/7/img008-00878.png
# /kaggle/input/digits/Digits/7/img008-00631.png
# /kaggle/input/digits/Digits/7/img008-00590.png
# /kaggle/input/digits/Digits/7/img008-00682.png
# /kaggle/input/digits/Digits/7/img008-00489.png
# /kaggle/input/digits/Digits/7/img008-00217.png
# /kaggle/input/digits/Digits/7/img008-00441.png
# /kaggle/input/digits/Digits/7/img008-00225.png
# /kaggle/input/digits/Digits/7/img008-00346.png
# /kaggle/input/digits/Digits/7/img008-00613.png
# /kaggle/input/digits/Digits/7/img008-00074.png
# /kaggle/input/digits/Digits/7/img008-00161.png
# /kaggle/input/digits/Digits/7/img008-01011.png
# /kaggle/input/digits/Digits/7/img008-00494.png
# /kaggle/input/digits/Digits/7/img008-00172.png
# /kaggle/input/digits/Digits/7/img008-00764.png
# /kaggle/input/digits/Digits/7/img008-00622.png
# /kaggle/input/digits/Digits/7/img008-00694.png
# /kaggle/input/digits/Digits/7/img008-00596.png
# /kaggle/input/digits/Digits/7/img008-00191.png
# /kaggle/input/digits/Digits/7/img008-00270.png
# /kaggle/input/digits/Digits/7/img008-00239.png
# /kaggle/input/digits/Digits/7/img008-00716.png
# /kaggle/input/digits/Digits/7/img008-00846.png
# /kaggle/input/digits/Digits/7/img008-00362.png
# /kaggle/input/digits/Digits/7/img008-00482.png
# /kaggle/input/digits/Digits/7/img008-01001.png
# /kaggle/input/digits/Digits/7/img008-00647.png
# /kaggle/input/digits/Digits/7/img008-00823.png
# /kaggle/input/digits/Digits/7/img008-00918.png
# /kaggle/input/digits/Digits/7/img008-00089.png
# /kaggle/input/digits/Digits/7/img008-00514.png
# /kaggle/input/digits/Digits/7/img008-00013.png
# /kaggle/input/digits/Digits/7/img008-00046.png
# /kaggle/input/digits/Digits/7/img008-00124.png
# /kaggle/input/digits/Digits/7/img008-00503.png
# /kaggle/input/digits/Digits/7/img008-00287.png
# /kaggle/input/digits/Digits/7/img008-00069.png
# /kaggle/input/digits/Digits/7/img008-00745.png
# /kaggle/input/digits/Digits/7/img008-00483.png
# /kaggle/input/digits/Digits/7/img008-00262.png
# /kaggle/input/digits/Digits/7/img008-00150.png
# /kaggle/input/digits/Digits/7/img008-00135.png
# /kaggle/input/digits/Digits/7/img008-00108.png
# /kaggle/input/digits/Digits/7/img008-00573.png
# /kaggle/input/digits/Digits/7/img008-00261.png
# /kaggle/input/digits/Digits/7/img008-00575.png
# /kaggle/input/digits/Digits/7/img008-00686.png
# /kaggle/input/digits/Digits/7/img008-00374.png
# /kaggle/input/digits/Digits/7/img008-00632.png
# /kaggle/input/digits/Digits/7/img008-00440.png
# /kaggle/input/digits/Digits/7/img008-00028.png
# /kaggle/input/digits/Digits/7/img008-00668.png
# /kaggle/input/digits/Digits/7/img008-00072.png
# /kaggle/input/digits/Digits/7/img008-00152.png
# /kaggle/input/digits/Digits/7/img008-00804.png
# /kaggle/input/digits/Digits/7/img008-00407.png
# /kaggle/input/digits/Digits/7/img008-00278.png
# /kaggle/input/digits/Digits/7/img008-00245.png
# /kaggle/input/digits/Digits/7/img008-00984.png
# /kaggle/input/digits/Digits/7/img008-00653.png
# /kaggle/input/digits/Digits/7/img008-00732.png
# /kaggle/input/digits/Digits/7/img008-00520.png
# /kaggle/input/digits/Digits/7/img008-00943.png
# /kaggle/input/digits/Digits/7/img008-00449.png
# /kaggle/input/digits/Digits/7/img008-00391.png
# /kaggle/input/digits/Digits/7/img008-00209.png
# /kaggle/input/digits/Digits/7/img008-00173.png
# /kaggle/input/digits/Digits/7/img008-00429.png
# /kaggle/input/digits/Digits/7/img008-00630.png
# /kaggle/input/digits/Digits/7/img008-00007.png
# /kaggle/input/digits/Digits/7/img008-00101.png
# /kaggle/input/digits/Digits/7/img008-00635.png
# /kaggle/input/digits/Digits/7/img008-00145.png
# /kaggle/input/digits/Digits/7/img008-00424.png
# /kaggle/input/digits/Digits/7/img008-00048.png
# /kaggle/input/digits/Digits/7/img008-00060.png
# /kaggle/input/digits/Digits/7/img008-00908.png
# /kaggle/input/digits/Digits/7/img008-00942.png
# /kaggle/input/digits/Digits/7/img008-00676.png
# /kaggle/input/digits/Digits/7/img008-00202.png
# /kaggle/input/digits/Digits/7/img008-00747.png
# /kaggle/input/digits/Digits/7/img008-00834.png
# /kaggle/input/digits/Digits/7/img008-00315.png
# /kaggle/input/digits/Digits/7/img008-00972.png
# /kaggle/input/digits/Digits/7/img008-00681.png
# /kaggle/input/digits/Digits/7/img008-00532.png
# /kaggle/input/digits/Digits/7/img008-00546.png
# /kaggle/input/digits/Digits/7/img008-00003.png
# /kaggle/input/digits/Digits/7/img008-00458.png
# /kaggle/input/digits/Digits/7/img008-00687.png
# /kaggle/input/digits/Digits/7/img008-00102.png
# /kaggle/input/digits/Digits/7/img008-00987.png
# /kaggle/input/digits/Digits/7/img008-00615.png
# /kaggle/input/digits/Digits/7/img008-00340.png
# /kaggle/input/digits/Digits/7/img008-00433.png
# /kaggle/input/digits/Digits/7/img008-00427.png
# /kaggle/input/digits/Digits/7/img008-00372.png
# /kaggle/input/digits/Digits/7/img008-00691.png
# /kaggle/input/digits/Digits/7/img008-00430.png
# /kaggle/input/digits/Digits/7/img008-00565.png
# /kaggle/input/digits/Digits/7/img008-00030.png
# /kaggle/input/digits/Digits/7/img008-00544.png
# /kaggle/input/digits/Digits/7/img008-00693.png
# /kaggle/input/digits/Digits/7/img008-00813.png
# /kaggle/input/digits/Digits/7/img008-00115.png
# /kaggle/input/digits/Digits/7/img008-00720.png
# /kaggle/input/digits/Digits/7/img008-00009.png
# /kaggle/input/digits/Digits/7/img008-00418.png
# /kaggle/input/digits/Digits/7/img008-00824.png
# /kaggle/input/digits/Digits/7/img008-00182.png
# /kaggle/input/digits/Digits/7/img008-00295.png
# /kaggle/input/digits/Digits/7/img008-00404.png
# /kaggle/input/digits/Digits/7/img008-00495.png
# /kaggle/input/digits/Digits/7/img008-00953.png
# /kaggle/input/digits/Digits/7/img008-00220.png
# /kaggle/input/digits/Digits/7/img008-00667.png
# /kaggle/input/digits/Digits/7/img008-00393.png
# /kaggle/input/digits/Digits/7/img008-00741.png
# /kaggle/input/digits/Digits/7/img008-00402.png
# /kaggle/input/digits/Digits/7/img008-00657.png
# /kaggle/input/digits/Digits/7/img008-00297.png
# /kaggle/input/digits/Digits/7/img008-00805.png
# /kaggle/input/digits/Digits/7/img008-00485.png
# /kaggle/input/digits/Digits/7/img008-00751.png
# /kaggle/input/digits/Digits/7/img008-00082.png
# /kaggle/input/digits/Digits/7/img008-00117.png
# /kaggle/input/digits/Digits/7/img008-00307.png
# /kaggle/input/digits/Digits/7/img008-00841.png
# /kaggle/input/digits/Digits/7/img008-00194.png
# /kaggle/input/digits/Digits/7/img008-00213.png
# /kaggle/input/digits/Digits/7/img008-00902.png
# /kaggle/input/digits/Digits/7/img008-00811.png
# /kaggle/input/digits/Digits/7/img008-00862.png
# /kaggle/input/digits/Digits/7/img008-00066.png
# /kaggle/input/digits/Digits/7/img008-00685.png
# /kaggle/input/digits/Digits/7/img008-00142.png
# /kaggle/input/digits/Digits/7/img008-00724.png
# /kaggle/input/digits/Digits/7/img008-00140.png
# /kaggle/input/digits/Digits/7/img008-00995.png
# /kaggle/input/digits/Digits/7/img008-00252.png
# /kaggle/input/digits/Digits/7/img008-00895.png
# /kaggle/input/digits/Digits/7/img008-00562.png
# /kaggle/input/digits/Digits/7/img008-00883.png
# /kaggle/input/digits/Digits/7/img008-00106.png
# /kaggle/input/digits/Digits/7/img008-00510.png
# /kaggle/input/digits/Digits/7/img008-00656.png
# /kaggle/input/digits/Digits/7/img008-00516.png
# /kaggle/input/digits/Digits/7/img008-00931.png
# /kaggle/input/digits/Digits/7/img008-00256.png
# /kaggle/input/digits/Digits/7/img008-00075.png
# /kaggle/input/digits/Digits/7/img008-00583.png
# /kaggle/input/digits/Digits/7/img008-00513.png
# /kaggle/input/digits/Digits/7/img008-00345.png
# /kaggle/input/digits/Digits/7/img008-00347.png
# /kaggle/input/digits/Digits/7/img008-00968.png
# /kaggle/input/digits/Digits/7/img008-00629.png
# /kaggle/input/digits/Digits/7/img008-00535.png
# /kaggle/input/digits/Digits/7/img008-00236.png
# /kaggle/input/digits/Digits/7/img008-00946.png
# /kaggle/input/digits/Digits/7/img008-00893.png
# /kaggle/input/digits/Digits/7/img008-00906.png
# /kaggle/input/digits/Digits/7/img008-00835.png
# /kaggle/input/digits/Digits/7/img008-00442.png
# /kaggle/input/digits/Digits/7/img008-00274.png
# /kaggle/input/digits/Digits/7/img008-00216.png
# /kaggle/input/digits/Digits/7/img008-00356.png
# /kaggle/input/digits/Digits/7/img008-00016.png
# /kaggle/input/digits/Digits/7/img008-00614.png
# /kaggle/input/digits/Digits/7/img008-00199.png
# /kaggle/input/digits/Digits/7/img008-00704.png
# /kaggle/input/digits/Digits/7/img008-00861.png
# /kaggle/input/digits/Digits/7/img008-00204.png
# /kaggle/input/digits/Digits/7/img008-00571.png
# /kaggle/input/digits/Digits/7/img008-00907.png
# /kaggle/input/digits/Digits/7/img008-00600.png
# /kaggle/input/digits/Digits/7/img008-00185.png
# /kaggle/input/digits/Digits/7/img008-00349.png
# /kaggle/input/digits/Digits/7/img008-00331.png
# /kaggle/input/digits/Digits/7/img008-00553.png
# /kaggle/input/digits/Digits/7/img008-00786.png
# /kaggle/input/digits/Digits/7/img008-00492.png
# /kaggle/input/digits/Digits/7/img008-00863.png
# /kaggle/input/digits/Digits/7/img008-00579.png
# /kaggle/input/digits/Digits/7/img008-00235.png
# /kaggle/input/digits/Digits/7/img008-00753.png
# /kaggle/input/digits/Digits/7/img008-00524.png
# /kaggle/input/digits/Digits/7/img008-00760.png
# /kaggle/input/digits/Digits/7/img008-00664.png
# /kaggle/input/digits/Digits/7/img008-00087.png
# /kaggle/input/digits/Digits/7/img008-00477.png
# /kaggle/input/digits/Digits/7/img008-00044.png
# /kaggle/input/digits/Digits/7/img008-00928.png
# /kaggle/input/digits/Digits/7/img008-00998.png
# /kaggle/input/digits/Digits/7/img008-00198.png
# /kaggle/input/digits/Digits/7/img008-00934.png
# /kaggle/input/digits/Digits/7/img008-00606.png
# /kaggle/input/digits/Digits/7/img008-00351.png
# /kaggle/input/digits/Digits/7/img008-00671.png
# /kaggle/input/digits/Digits/7/img008-00904.png
# /kaggle/input/digits/Digits/7/img008-00757.png
# /kaggle/input/digits/Digits/7/img008-00980.png
# /kaggle/input/digits/Digits/7/img008-00935.png
# /kaggle/input/digits/Digits/7/img008-00511.png
# /kaggle/input/digits/Digits/7/img008-00819.png
# /kaggle/input/digits/Digits/7/img008-00281.png
# /kaggle/input/digits/Digits/7/img008-00652.png
# /kaggle/input/digits/Digits/7/img008-00858.png
# /kaggle/input/digits/Digits/7/img008-00272.png
# /kaggle/input/digits/Digits/7/img008-00830.png
# /kaggle/input/digits/Digits/7/img008-00175.png
# /kaggle/input/digits/Digits/7/img008-00157.png
# /kaggle/input/digits/Digits/7/img008-00162.png
# /kaggle/input/digits/Digits/7/img008-00296.png
# /kaggle/input/digits/Digits/7/img008-00610.png
# /kaggle/input/digits/Digits/7/img008-00230.png
# /kaggle/input/digits/Digits/7/img008-00680.png
# /kaggle/input/digits/Digits/7/img008-00019.png
# /kaggle/input/digits/Digits/7/img008-00293.png
# /kaggle/input/digits/Digits/7/img008-00099.png
# /kaggle/input/digits/Digits/7/img008-00163.png
# /kaggle/input/digits/Digits/7/img008-00788.png
# /kaggle/input/digits/Digits/7/img008-00832.png
# /kaggle/input/digits/Digits/7/img008-01015.png
# /kaggle/input/digits/Digits/7/img008-00621.png
# /kaggle/input/digits/Digits/7/img008-00222.png
# /kaggle/input/digits/Digits/7/img008-00337.png
# /kaggle/input/digits/Digits/7/img008-00335.png
# /kaggle/input/digits/Digits/7/img008-00938.png
# /kaggle/input/digits/Digits/7/img008-00290.png
# /kaggle/input/digits/Digits/7/img008-00531.png
# /kaggle/input/digits/Digits/7/img008-00207.png
# /kaggle/input/digits/Digits/7/img008-00011.png
# /kaggle/input/digits/Digits/7/img008-00558.png
# /kaggle/input/digits/Digits/7/img008-00710.png
# /kaggle/input/digits/Digits/7/img008-00726.png
# /kaggle/input/digits/Digits/7/img008-00400.png
# /kaggle/input/digits/Digits/7/img008-00174.png
# /kaggle/input/digits/Digits/7/img008-00965.png
# /kaggle/input/digits/Digits/7/img008-00446.png
# /kaggle/input/digits/Digits/7/img008-00586.png
# /kaggle/input/digits/Digits/7/img008-00539.png
# /kaggle/input/digits/Digits/7/img008-01014.png
# /kaggle/input/digits/Digits/7/img008-00359.png
# /kaggle/input/digits/Digits/7/img008-00241.png
# /kaggle/input/digits/Digits/7/img008-00771.png
# /kaggle/input/digits/Digits/7/img008-00568.png
# /kaggle/input/digits/Digits/7/img008-00550.png
# /kaggle/input/digits/Digits/7/img008-00559.png
# /kaggle/input/digits/Digits/7/img008-00338.png
# /kaggle/input/digits/Digits/7/img008-00334.png
# /kaggle/input/digits/Digits/7/img008-00378.png
# /kaggle/input/digits/Digits/7/img008-00534.png
# /kaggle/input/digits/Digits/7/img008-00729.png
# /kaggle/input/digits/Digits/7/img008-00820.png
# /kaggle/input/digits/Digits/7/img008-00139.png
# /kaggle/input/digits/Digits/7/img008-00022.png
# /kaggle/input/digits/Digits/7/img008-00727.png
# /kaggle/input/digits/Digits/7/img008-00971.png
# /kaggle/input/digits/Digits/7/img008-00451.png
# /kaggle/input/digits/Digits/7/img008-00096.png
# /kaggle/input/digits/Digits/7/img008-00640.png
# /kaggle/input/digits/Digits/7/img008-00076.png
# /kaggle/input/digits/Digits/7/img008-00244.png
# /kaggle/input/digits/Digits/7/img008-00103.png
# /kaggle/input/digits/Digits/7/img008-00370.png
# /kaggle/input/digits/Digits/7/img008-00240.png
# /kaggle/input/digits/Digits/7/img008-00057.png
# /kaggle/input/digits/Digits/7/img008-00886.png
# /kaggle/input/digits/Digits/7/img008-00243.png
# /kaggle/input/digits/Digits/7/img008-00949.png
# /kaggle/input/digits/Digits/7/img008-00132.png
# /kaggle/input/digits/Digits/7/img008-00915.png
# /kaggle/input/digits/Digits/7/img008-00268.png
# /kaggle/input/digits/Digits/7/img008-00133.png
# /kaggle/input/digits/Digits/7/img008-00109.png
# /kaggle/input/digits/Digits/7/img008-00266.png
# /kaggle/input/digits/Digits/7/img008-00352.png
# /kaggle/input/digits/Digits/7/img008-00808.png
# /kaggle/input/digits/Digits/7/img008-00993.png
# /kaggle/input/digits/Digits/7/img008-00642.png
# /kaggle/input/digits/Digits/7/img008-00617.png
# /kaggle/input/digits/Digits/7/img008-00744.png
# /kaggle/input/digits/Digits/7/img008-00564.png
# /kaggle/input/digits/Digits/7/img008-00725.png
# /kaggle/input/digits/Digits/7/img008-00205.png
# /kaggle/input/digits/Digits/7/img008-00793.png
# /kaggle/input/digits/Digits/7/img008-00777.png
# /kaggle/input/digits/Digits/7/img008-00277.png
# /kaggle/input/digits/Digits/7/img008-00602.png
# /kaggle/input/digits/Digits/7/img008-00933.png
# /kaggle/input/digits/Digits/7/img008-00916.png
# /kaggle/input/digits/Digits/7/img008-00882.png
# /kaggle/input/digits/Digits/7/img008-00156.png
# /kaggle/input/digits/Digits/7/img008-00179.png
# /kaggle/input/digits/Digits/7/img008-00634.png
# /kaggle/input/digits/Digits/7/img008-00229.png
# /kaggle/input/digits/Digits/7/img008-00913.png
# /kaggle/input/digits/Digits/7/img008-00829.png
# /kaggle/input/digits/Digits/7/img008-00940.png
# /kaggle/input/digits/Digits/7/img008-00025.png
# /kaggle/input/digits/Digits/7/img008-00288.png
# /kaggle/input/digits/Digits/7/img008-00800.png
# /kaggle/input/digits/Digits/7/img008-00791.png
# /kaggle/input/digits/Digits/7/img008-00666.png
# /kaggle/input/digits/Digits/7/img008-00845.png
# /kaggle/input/digits/Digits/7/img008-00665.png
# /kaggle/input/digits/Digits/7/img008-00991.png
# /kaggle/input/digits/Digits/7/img008-00273.png
# /kaggle/input/digits/Digits/7/img008-00836.png
# /kaggle/input/digits/Digits/7/img008-00628.png
# /kaggle/input/digits/Digits/7/img008-00385.png
# /kaggle/input/digits/Digits/7/img008-00218.png
# /kaggle/input/digits/Digits/7/img008-00670.png
# /kaggle/input/digits/Digits/7/img008-00091.png
# /kaggle/input/digits/Digits/7/img008-00643.png
# /kaggle/input/digits/Digits/7/img008-00085.png
# /kaggle/input/digits/Digits/7/img008-00795.png
# /kaggle/input/digits/Digits/7/img008-00880.png
# /kaggle/input/digits/Digits/7/img008-00831.png
# /kaggle/input/digits/Digits/7/img008-00453.png
# /kaggle/input/digits/Digits/7/img008-00447.png
# /kaggle/input/digits/Digits/7/img008-00591.png
# /kaggle/input/digits/Digits/7/img008-00734.png
# /kaggle/input/digits/Digits/7/img008-00383.png
# /kaggle/input/digits/Digits/7/img008-00689.png
# /kaggle/input/digits/Digits/7/img008-00782.png
# /kaggle/input/digits/Digits/7/img008-00203.png
# /kaggle/input/digits/Digits/7/img008-00839.png
# /kaggle/input/digits/Digits/7/img008-00567.png
# /kaggle/input/digits/Digits/7/img008-00435.png
# /kaggle/input/digits/Digits/7/img008-00068.png
# /kaggle/input/digits/Digits/7/img008-00020.png
# /kaggle/input/digits/Digits/7/img008-00439.png
# /kaggle/input/digits/Digits/7/img008-01007.png
# /kaggle/input/digits/Digits/7/img008-00187.png
# /kaggle/input/digits/Digits/7/img008-00310.png
# /kaggle/input/digits/Digits/7/img008-00134.png
# /kaggle/input/digits/Digits/7/img008-00165.png
# /kaggle/input/digits/Digits/7/img008-00636.png
# /kaggle/input/digits/Digits/7/img008-00473.png
# /kaggle/input/digits/Digits/7/img008-00144.png
# /kaggle/input/digits/Digits/7/img008-00130.png
# /kaggle/input/digits/Digits/7/img008-00233.png
# /kaggle/input/digits/Digits/7/img008-00399.png
# /kaggle/input/digits/Digits/7/img008-00756.png
# /kaggle/input/digits/Digits/7/img008-00226.png
# /kaggle/input/digits/Digits/7/img008-00113.png
# /kaggle/input/digits/Digits/7/img008-00403.png
# /kaggle/input/digits/Digits/7/img008-00111.png
# /kaggle/input/digits/Digits/7/img008-00936.png
# /kaggle/input/digits/Digits/7/img008-00097.png
# /kaggle/input/digits/Digits/7/img008-00796.png
# /kaggle/input/digits/Digits/7/img008-00384.png
# /kaggle/input/digits/Digits/7/img008-00633.png
# /kaggle/input/digits/Digits/7/img008-00444.png
# /kaggle/input/digits/Digits/7/img008-00955.png
# /kaggle/input/digits/Digits/7/img008-00237.png
# /kaggle/input/digits/Digits/7/img008-00086.png
# /kaggle/input/digits/Digits/7/img008-00731.png
# /kaggle/input/digits/Digits/7/img008-00126.png
# /kaggle/input/digits/Digits/7/img008-01006.png
# /kaggle/input/digits/Digits/7/img008-00093.png
# /kaggle/input/digits/Digits/7/img008-00822.png
# /kaggle/input/digits/Digits/7/img008-00289.png
# /kaggle/input/digits/Digits/7/img008-01013.png
# /kaggle/input/digits/Digits/7/img008-00079.png
# /kaggle/input/digits/Digits/7/img008-00457.png
# /kaggle/input/digits/Digits/7/img008-00897.png
# /kaggle/input/digits/Digits/7/img008-00781.png
# /kaggle/input/digits/Digits/7/img008-00555.png
# /kaggle/input/digits/Digits/7/img008-00627.png
# /kaggle/input/digits/Digits/7/img008-00100.png
# /kaggle/input/digits/Digits/7/img008-00242.png
# /kaggle/input/digits/Digits/7/img008-00758.png
# /kaggle/input/digits/Digits/7/img008-00840.png
# /kaggle/input/digits/Digits/7/img008-00121.png
# /kaggle/input/digits/Digits/7/img008-00759.png
# /kaggle/input/digits/Digits/7/img008-00151.png
# /kaggle/input/digits/Digits/2/img003-00303.png
# /kaggle/input/digits/Digits/2/img003-00097.png
# /kaggle/input/digits/Digits/2/img003-00388.png
# /kaggle/input/digits/Digits/2/img003-00257.png
# /kaggle/input/digits/Digits/2/img003-00033.png
# ...
# /kaggle/input/sudoku-box-detection/aug/_35_9223478.jpeg
# /kaggle/input/sudoku-box-detection/aug/_198_2219164.jpeg
# /kaggle/input/sudoku-box-detection/aug/_74_5595600.jpeg
# /kaggle/input/sudoku-box-detection/aug/_102_455934.jpeg
# /kaggle/input/sudoku-box-detection/aug/_291_3316988.jpeg
# /kaggle/input/sudoku-box-detection/aug/_78_9518463.jpeg
# /kaggle/input/sudoku-box-detection/aug/_193_6834237.jpeg
# /kaggle/input/sudoku-box-detection/aug/_16_7438795.jpeg
# /kaggle/input/sudoku-box-detection/aug/_82_6202818.jpeg
# /kaggle/input/sudoku-box-detection/aug/_223_7296579.jpeg
# /kaggle/input/sudoku-box-detection/aug/_250_241500.jpeg
# /kaggle/input/sudoku-box-detection/aug/_241_279119.jpeg
# /kaggle/input/sudoku-box-detection/aug/_189_2395109.jpeg
# /kaggle/input/sudoku-box-detection/aug/_24_191029.jpeg
# /kaggle/input/sudoku-box-detection/aug/_73_4388879.jpeg
# /kaggle/input/sudoku-box-detection/aug/_134_3831525.jpeg
# /kaggle/input/sudoku-box-detection/aug/_107_8161045.jpeg
# /kaggle/input/sudoku-box-detection/aug/_286_962698.jpeg
# /kaggle/input/sudoku-box-detection/aug/_215_7567613.jpeg
# /kaggle/input/sudoku-box-detection/aug/_38_4338143.jpeg
# /kaggle/input/sudoku-box-detection/aug/_199_8341037.jpeg
# /kaggle/input/sudoku-box-detection/aug/_75_8170128.jpeg
# /kaggle/input/sudoku-box-detection/aug/_23_184116.jpeg
# /kaggle/input/sudoku-box-detection/aug/_280_9517173.jpeg
# /kaggle/input/sudoku-box-detection/aug/_262_4880473.jpeg
# /kaggle/input/sudoku-box-detection/aug/_238_5261711.jpeg
# /kaggle/input/sudoku-box-detection/aug/_139_5276351.jpeg
# /kaggle/input/sudoku-box-detection/aug/_99_7181117.jpeg
# /kaggle/input/sudoku-box-detection/aug/_0_7670549.jpeg
# /kaggle/input/sudoku-box-detection/aug/_86_8235865.jpeg
# /kaggle/input/sudoku-box-detection/aug/_213_9204346.jpeg
# /kaggle/input/sudoku-box-detection/aug/_145_1450706.jpeg
# /kaggle/input/sudoku-box-detection/aug/_61_6669781.jpeg
# /kaggle/input/sudoku-box-detection/aug/_290_1461537.jpeg
# /kaggle/input/sudoku-box-detection/aug/_85_1050059.jpeg
# /kaggle/input/sudoku-box-detection/aug/_157_5640060.jpeg
# /kaggle/input/sudoku-box-detection/aug/_75_5270448.jpeg
# /kaggle/input/sudoku-box-detection/aug/_231_4678938.jpeg
# /kaggle/input/sudoku-box-detection/aug/_44_523447.jpeg
# /kaggle/input/sudoku-box-detection/aug/_98_1796210.jpeg
# /kaggle/input/sudoku-box-detection/aug/_103_5668755.jpeg
# /kaggle/input/sudoku-box-detection/aug/_211_9124978.jpeg
# /kaggle/input/sudoku-box-detection/aug/_253_7612728.jpeg
# /kaggle/input/sudoku-box-detection/aug/_145_2868183.jpeg
# /kaggle/input/sudoku-box-detection/aug/_190_6170052.jpeg
# /kaggle/input/sudoku-box-detection/aug/_99_276406.jpeg
# /kaggle/input/sudoku-box-detection/aug/_234_1592945.jpeg
# /kaggle/input/sudoku-box-detection/aug/_84_1820232.jpeg
# /kaggle/input/sudoku-box-detection/aug/_57_8200822.jpeg
# /kaggle/input/sudoku-box-detection/aug/_55_2480006.jpeg
# /kaggle/input/sudoku-box-detection/aug/_291_4676089.jpeg
# /kaggle/input/sudoku-box-detection/aug/_96_8648511.jpeg
# /kaggle/input/sudoku-box-detection/aug/_198_8180132.jpeg
# /kaggle/input/sudoku-box-detection/aug/_180_7800239.jpeg
# /kaggle/input/sudoku-box-detection/aug/_83_2722998.jpeg
# /kaggle/input/sudoku-box-detection/aug/_14_9528744.jpeg
# /kaggle/input/sudoku-box-detection/aug/_247_2568481.jpeg
# /kaggle/input/sudoku-box-detection/aug/_92_974440.jpeg
# /kaggle/input/sudoku-box-detection/aug/_185_3905165.jpeg
# /kaggle/input/sudoku-box-detection/aug/_3_8556815.jpeg
# /kaggle/input/sudoku-box-detection/aug/_116_8495530.jpeg
# /kaggle/input/sudoku-box-detection/aug/_108_3336511.jpeg
# /kaggle/input/sudoku-box-detection/aug/_7_7661130.jpeg
# /kaggle/input/sudoku-box-detection/aug/_295_9169566.jpeg
# /kaggle/input/sudoku-box-detection/aug/_29_3581824.jpeg
# /kaggle/input/sudoku-box-detection/aug/_185_7684251.jpeg
# /kaggle/input/sudoku-box-detection/aug/_139_4644658.jpeg
# /kaggle/input/sudoku-box-detection/aug/_104_9113400.jpeg
# /kaggle/input/sudoku-box-detection/aug/_103_9385084.jpeg
# /kaggle/input/sudoku-box-detection/aug/_154_6843305.jpeg
# /kaggle/input/sudoku-box-detection/aug/_270_9599953.jpeg
# /kaggle/input/sudoku-box-detection/aug/_13_2916341.jpeg
# /kaggle/input/sudoku-box-detection/aug/_178_2735524.jpeg
# /kaggle/input/sudoku-box-detection/aug/_91_299927.jpeg
# /kaggle/input/sudoku-box-detection/aug/_107_3354406.jpeg
# /kaggle/input/sudoku-box-detection/aug/_28_5999403.jpeg
# /kaggle/input/sudoku-box-detection/aug/_151_8323923.jpeg
# /kaggle/input/sudoku-box-detection/aug/_289_8017563.jpeg
# /kaggle/input/sudoku-box-detection/aug/_21_3150588.jpeg
# /kaggle/input/sudoku-box-detection/aug/_82_3666081.jpeg
# /kaggle/input/sudoku-box-detection/aug/_155_6957228.jpeg
# /kaggle/input/sudoku-box-detection/aug/_86_8921846.jpeg
# /kaggle/input/sudoku-box-detection/aug/_59_6020192.jpeg
# /kaggle/input/sudoku-box-detection/aug/_118_519887.jpeg
# /kaggle/input/sudoku-box-detection/aug/_291_4388839.jpeg
# /kaggle/input/sudoku-box-detection/aug/_5_4049495.jpeg
# /kaggle/input/sudoku-box-detection/aug/_297_4407266.jpeg
# /kaggle/input/sudoku-box-detection/aug/_36_3913769.jpeg
# /kaggle/input/sudoku-box-detection/aug/_11_7287618.jpeg
# /kaggle/input/sudoku-box-detection/aug/_201_7866262.jpeg
# /kaggle/input/sudoku-box-detection/aug/_67_9206401.jpeg
# /kaggle/input/sudoku-box-detection/aug/_11_257486.jpeg
# /kaggle/input/sudoku-box-detection/aug/_55_2206904.jpeg
# /kaggle/input/sudoku-box-detection/aug/_149_7543047.jpeg
# /kaggle/input/sudoku-box-detection/aug/_239_5063839.jpeg
# /kaggle/input/sudoku-box-detection/aug/_211_7907581.jpeg
# /kaggle/input/sudoku-box-detection/aug/_57_8076331.jpeg
# /kaggle/input/sudoku-box-detection/aug/_286_4710181.jpeg
# /kaggle/input/sudoku-box-detection/aug/_109_8801290.jpeg
# /kaggle/input/sudoku-box-detection/aug/_16_5655697.jpeg
# /kaggle/input/sudoku-box-detection/aug/_108_8937723.jpeg
# /kaggle/input/sudoku-box-detection/aug/_94_4024106.jpeg
# /kaggle/input/sudoku-box-detection/aug/_6_7039355.jpeg
# /kaggle/input/sudoku-box-detection/aug/_141_6817675.jpeg
# /kaggle/input/sudoku-box-detection/aug/_243_3958597.jpeg
# /kaggle/input/sudoku-box-detection/aug/_18_4729122.jpeg
# /kaggle/input/sudoku-box-detection/aug/_261_291126.jpeg
# /kaggle/input/sudoku-box-detection/aug/_295_9663697.jpeg
# /kaggle/input/sudoku-box-detection/aug/_117_9949422.jpeg
# /kaggle/input/sudoku-box-detection/aug/_251_4326719.jpeg
# /kaggle/input/sudoku-box-detection/aug/_30_2158050.jpeg
# /kaggle/input/sudoku-box-detection/aug/_151_3089618.jpeg
# /kaggle/input/sudoku-box-detection/aug/_272_8845794.jpeg
# /kaggle/input/sudoku-box-detection/aug/_219_8833276.jpeg
# /kaggle/input/sudoku-box-detection/aug/_152_808666.jpeg
# /kaggle/input/sudoku-box-detection/aug/_168_6665750.jpeg
# /kaggle/input/sudoku-box-detection/aug/_39_8650792.jpeg
# /kaggle/input/sudoku-box-detection/aug/_199_3425563.jpeg
# /kaggle/input/sudoku-box-detection/aug/_256_1103674.jpeg
# /kaggle/input/sudoku-box-detection/aug/_94_3125453.jpeg
# /kaggle/input/sudoku-box-detection/aug/_102_5772710.jpeg
# /kaggle/input/sudoku-box-detection/aug/_278_3978762.jpeg
# /kaggle/input/sudoku-box-detection/aug/_86_6714310.jpeg
# /kaggle/input/sudoku-box-detection/aug/_31_5677817.jpeg
# /kaggle/input/sudoku-box-detection/aug/_269_4046143.jpeg
# /kaggle/input/sudoku-box-detection/aug/_261_5568430.jpeg
# /kaggle/input/sudoku-box-detection/aug/_94_8577052.jpeg
# /kaggle/input/sudoku-box-detection/aug/_97_4651659.jpeg
# /kaggle/input/sudoku-box-detection/aug/_36_83825.jpeg
# /kaggle/input/sudoku-box-detection/aug/_6_344837.jpeg
# /kaggle/input/sudoku-box-detection/aug/_164_2594551.jpeg
# /kaggle/input/sudoku-box-detection/aug/_203_4390200.jpeg
# /kaggle/input/sudoku-box-detection/aug/_84_3444602.jpeg
# /kaggle/input/sudoku-box-detection/aug/_163_2702070.jpeg
# /kaggle/input/sudoku-box-detection/aug/_50_576026.jpeg
# /kaggle/input/sudoku-box-detection/aug/_209_7448494.jpeg
# /kaggle/input/sudoku-box-detection/aug/_297_3227284.jpeg
# /kaggle/input/sudoku-box-detection/aug/_67_5885942.jpeg
# /kaggle/input/sudoku-box-detection/aug/_96_6217344.jpeg
# /kaggle/input/sudoku-box-detection/aug/_193_9093451.jpeg
# /kaggle/input/sudoku-box-detection/aug/_127_349824.jpeg
# /kaggle/input/sudoku-box-detection/aug/_31_2062632.jpeg
# /kaggle/input/sudoku-box-detection/aug/_218_2681951.jpeg
# /kaggle/input/sudoku-box-detection/aug/_15_4643212.jpeg
# /kaggle/input/sudoku-box-detection/aug/_194_1051898.jpeg
# /kaggle/input/sudoku-box-detection/aug/_21_1917507.jpeg
# /kaggle/input/sudoku-box-detection/aug/_38_8986169.jpeg
# /kaggle/input/sudoku-box-detection/aug/_88_6494131.jpeg
# /kaggle/input/sudoku-box-detection/aug/_13_8208301.jpeg
# /kaggle/input/sudoku-box-detection/aug/_276_4397066.jpeg
# /kaggle/input/sudoku-box-detection/aug/_58_7982177.jpeg
# /kaggle/input/sudoku-box-detection/aug/_282_3385892.jpeg
# /kaggle/input/sudoku-box-detection/aug/_2_1351224.jpeg
# /kaggle/input/sudoku-box-detection/aug/_181_6654378.jpeg
# /kaggle/input/sudoku-box-detection/aug/_193_4727715.jpeg
# /kaggle/input/sudoku-box-detection/aug/_45_6435164.jpeg
# /kaggle/input/sudoku-box-detection/aug/_96_3828138.jpeg
# /kaggle/input/sudoku-box-detection/aug/_32_9243.jpeg
# /kaggle/input/sudoku-box-detection/aug/_11_4263065.jpeg
# /kaggle/input/sudoku-box-detection/aug/_291_3561461.jpeg
# /kaggle/input/sudoku-box-detection/aug/_178_2135366.jpeg
# /kaggle/input/sudoku-box-detection/aug/_107_9296689.jpeg
# /kaggle/input/sudoku-box-detection/aug/_259_5669778.jpeg
# /kaggle/input/sudoku-box-detection/aug/_25_6973103.jpeg
# /kaggle/input/sudoku-box-detection/aug/_105_5489689.jpeg
# /kaggle/input/sudoku-box-detection/aug/_71_5589515.jpeg
# /kaggle/input/sudoku-box-detection/aug/_13_206693.jpeg
# /kaggle/input/sudoku-box-detection/aug/_227_5013286.jpeg
# /kaggle/input/sudoku-box-detection/aug/_149_6173716.jpeg
# /kaggle/input/sudoku-box-detection/aug/_216_6857458.jpeg
# /kaggle/input/sudoku-box-detection/aug/_108_2776757.jpeg
# /kaggle/input/sudoku-box-detection/aug/_110_5614066.jpeg
# /kaggle/input/sudoku-box-detection/aug/_42_8335904.jpeg
# /kaggle/input/sudoku-box-detection/aug/_73_8516323.jpeg
# /kaggle/input/sudoku-box-detection/aug/_280_878397.jpeg
# /kaggle/input/sudoku-box-detection/aug/_197_5559099.jpeg
# /kaggle/input/sudoku-box-detection/aug/_19_3067699.jpeg
# /kaggle/input/sudoku-box-detection/aug/_117_9590955.jpeg
# /kaggle/input/sudoku-box-detection/aug/_104_5931730.jpeg
# /kaggle/input/sudoku-box-detection/aug/_105_5857026.jpeg
# /kaggle/input/sudoku-box-detection/aug/_289_9313418.jpeg
# /kaggle/input/sudoku-box-detection/aug/_180_3272201.jpeg
# /kaggle/input/sudoku-box-detection/aug/_284_7965411.jpeg
# /kaggle/input/sudoku-box-detection/aug/_136_4079714.jpeg
# /kaggle/input/sudoku-box-detection/aug/_57_9512806.jpeg
# /kaggle/input/sudoku-box-detection/aug/_36_3651540.jpeg
# /kaggle/input/sudoku-box-detection/aug/_271_2561203.jpeg
# /kaggle/input/sudoku-box-detection/aug/_70_1603042.jpeg
# /kaggle/input/sudoku-box-detection/aug/_192_2235981.jpeg
# /kaggle/input/sudoku-box-detection/aug/_125_1653380.jpeg
# /kaggle/input/sudoku-box-detection/aug/_138_1822033.jpeg
# /kaggle/input/sudoku-box-detection/aug/_73_5214880.jpeg
# /kaggle/input/sudoku-box-detection/aug/_55_1442950.jpeg
# /kaggle/input/sudoku-box-detection/aug/_139_9456064.jpeg
# /kaggle/input/sudoku-box-detection/aug/_82_7707873.jpeg
# /kaggle/input/sudoku-box-detection/aug/_38_2699312.jpeg
# /kaggle/input/sudoku-box-detection/aug/_109_786499.jpeg
# /kaggle/input/sudoku-box-detection/aug/_1_3567067.jpeg
# /kaggle/input/sudoku-box-detection/aug/_191_4982836.jpeg
# /kaggle/input/sudoku-box-detection/aug/_70_7718036.jpeg
# /kaggle/input/sudoku-box-detection/aug/_12_8497224.jpeg
# /kaggle/input/sudoku-box-detection/aug/_83_443391.jpeg
# /kaggle/input/sudoku-box-detection/aug/_21_307729.jpeg
# /kaggle/input/sudoku-box-detection/aug/_0_8213354.jpeg
# /kaggle/input/sudoku-box-detection/aug/_47_8534627.jpeg
# /kaggle/input/sudoku-box-detection/aug/_25_6481403.jpeg
# /kaggle/input/sudoku-box-detection/aug/_159_4772062.jpeg
# /kaggle/input/sudoku-box-detection/aug/_217_7864565.jpeg
# /kaggle/input/sudoku-box-detection/aug/_189_9898517.jpeg
# /kaggle/input/sudoku-box-detection/aug/_21_1158561.jpeg
# /kaggle/input/sudoku-box-detection/aug/_28_3764588.jpeg
# /kaggle/input/sudoku-box-detection/aug/_59_2925680.jpeg
# /kaggle/input/sudoku-box-detection/aug/_265_7396989.jpeg
# /kaggle/input/sudoku-box-detection/aug/_53_9714265.jpeg
# /kaggle/input/sudoku-box-detection/aug/_213_5448394.jpeg
# /kaggle/input/sudoku-box-detection/aug/_102_3010711.jpeg
# /kaggle/input/sudoku-box-detection/aug/_293_7090686.jpeg
# /kaggle/input/sudoku-box-detection/aug/_103_7166222.jpeg
# /kaggle/input/sudoku-box-detection/aug/_100_836605.jpeg
# /kaggle/input/sudoku-box-detection/aug/_235_6648930.jpeg
# /kaggle/input/sudoku-box-detection/aug/_14_6309664.jpeg
# /kaggle/input/sudoku-box-detection/aug/_49_5889338.jpeg
# /kaggle/input/sudoku-box-detection/aug/_74_8381171.jpeg
# /kaggle/input/sudoku-box-detection/aug/_207_8724933.jpeg
# /kaggle/input/sudoku-box-detection/aug/_96_9815492.jpeg
# /kaggle/input/sudoku-box-detection/aug/_80_6187838.jpeg
# /kaggle/input/sudoku-box-detection/aug/_59_4943353.jpeg
# /kaggle/input/sudoku-box-detection/aug/_97_9616548.jpeg
# /kaggle/input/sudoku-box-detection/aug/_285_434919.jpeg
# /kaggle/input/sudoku-box-detection/aug/_18_1170647.jpeg
# /kaggle/input/sudoku-box-detection/aug/_275_7443029.jpeg
# /kaggle/input/sudoku-box-detection/aug/_209_4097154.jpeg
# /kaggle/input/sudoku-box-detection/aug/_286_8833925.jpeg
# /kaggle/input/sudoku-box-detection/aug/_195_252637.jpeg
# /kaggle/input/sudoku-box-detection/aug/_215_661891.jpeg
# /kaggle/input/sudoku-box-detection/aug/_194_7292567.jpeg
# /kaggle/input/sudoku-box-detection/aug/_57_1602494.jpeg
# /kaggle/input/sudoku-box-detection/aug/_261_9069631.jpeg
# /kaggle/input/sudoku-box-detection/aug/_91_8292846.jpeg
# /kaggle/input/sudoku-box-detection/aug/_189_9780639.jpeg
# /kaggle/input/sudoku-box-detection/aug/_181_4465267.jpeg
# /kaggle/input/sudoku-box-detection/aug/_70_9303998.jpeg
# /kaggle/input/sudoku-box-detection/aug/_11_8777756.jpeg
# /kaggle/input/sudoku-box-detection/aug/_267_5166711.jpeg
# /kaggle/input/sudoku-box-detection/aug/_200_945838.jpeg
# /kaggle/input/sudoku-box-detection/aug/_238_4699051.jpeg
# /kaggle/input/sudoku-box-detection/aug/_271_8990742.jpeg
# /kaggle/input/sudoku-box-detection/aug/_197_2582501.jpeg
# /kaggle/input/sudoku-box-detection/aug/_49_5418713.jpeg
# /kaggle/input/sudoku-box-detection/aug/_96_9912963.jpeg
# /kaggle/input/sudoku-box-detection/aug/_81_1547064.jpeg
# /kaggle/input/sudoku-box-detection/aug/_272_4988292.jpeg
# /kaggle/input/sudoku-box-detection/aug/_284_6525124.jpeg
# /kaggle/input/sudoku-box-detection/aug/_298_5816601.jpeg
# /kaggle/input/sudoku-box-detection/aug/_96_6578829.jpeg
# /kaggle/input/sudoku-box-detection/aug/_205_756068.jpeg
# /kaggle/input/sudoku-box-detection/aug/_166_7293329.jpeg
# /kaggle/input/sudoku-box-detection/aug/_136_7179668.jpeg
# /kaggle/input/sudoku-box-detection/aug/_114_4539969.jpeg
# /kaggle/input/sudoku-box-detection/aug/_34_369826.jpeg
# /kaggle/input/sudoku-box-detection/aug/_30_1014539.jpeg
# /kaggle/input/sudoku-box-detection/aug/_291_6780568.jpeg
# /kaggle/input/sudoku-box-detection/aug/_90_8924109.jpeg
# /kaggle/input/sudoku-box-detection/aug/_38_5548862.jpeg
# /kaggle/input/sudoku-box-detection/aug/_257_5482535.jpeg
# /kaggle/input/sudoku-box-detection/aug/_67_3874715.jpeg
# /kaggle/input/sudoku-box-detection/aug/_65_3757596.jpeg
# /kaggle/input/sudoku-box-detection/aug/_262_4919916.jpeg
# /kaggle/input/sudoku-box-detection/aug/_123_2363056.jpeg
# /kaggle/input/sudoku-box-detection/aug/_21_3151013.jpeg
# /kaggle/input/sudoku-box-detection/aug/_19_2089646.jpeg
# /kaggle/input/sudoku-box-detection/aug/_247_1356028.jpeg
# /kaggle/input/sudoku-box-detection/aug/_3_1307755.jpeg
# /kaggle/input/sudoku-box-detection/aug/_29_5300034.jpeg
# /kaggle/input/sudoku-box-detection/aug/_117_8261703.jpeg
# /kaggle/input/sudoku-box-detection/aug/_206_4167517.jpeg
# /kaggle/input/sudoku-box-detection/aug/_202_4460801.jpeg
# /kaggle/input/sudoku-box-detection/aug/_218_3492862.jpeg
# /kaggle/input/sudoku-box-detection/aug/_14_7025682.jpeg
# /kaggle/input/sudoku-box-detection/aug/_93_1272433.jpeg
# /kaggle/input/sudoku-box-detection/aug/_152_5343548.jpeg
# /kaggle/input/sudoku-box-detection/aug/_285_9375601.jpeg
# /kaggle/input/sudoku-box-detection/aug/_128_3843449.jpeg

# %% [markdown]
# # <h1 style='background:#4686C8; border:0; color:#5CE1E6'><center>SUDOKU PUZZLE </center></h1>
#
# The project is divided into three parts
#
# **Part One: Digit Classification Model**
#
# Build and train a neural network on the Chars74K image dataset for digits. This will be further used in classifying the digits in the image.
#
# **Part Two: Detecting And Reading The Sudoku From An Image**
#
# Identify the sudoku puzzle in an image using OpenCV-library.
# Classify the digits in the detected sudoku puzzle using the model made in part one.
# Getting the values of the cells in the sudoku in for of array.
#
# **Part Three: Solving The Puzzle**
#
# The array is converted into matrix.
# The given puzzle is are solved using recursion.
#
#
# <h1 style='background:#4686C8; border:0; color:#5CE1E6'><center>TABLE OF CONTENTS</center></h1>
#
# [1. IMPORTING LIBRARIES](#1)
#
# [2. PART ONE: DIGIT CLASSIFICATION MODEL](#2)
#
# [3. LOADING DATA](#3)
#
# [4. SPLITTING DATASET](#4)
#
# [5. MODEL BUILDING](#5)
#
# [6. PART TWO: READING THE SUDOKU PUZZLE](#6)
#
# [7. DETECTING CONTOUR](#7)
#
# [8. SPLITTING THE CELLS AND CLASSIFYING DIGITS](#8)
#
# [9. PART THREE: SOLVING THE SUDOKU](#9)
#
# [10. END](#10)
#
#
#  <a id="1"></a>
# # **<span style="color:#4686C8;">IMPORTING LIBRARIES</span>**

# %%
#Loading Libraries

import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os, random
import cv2
from glob import glob
import sklearn
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing.image import ImageDataGenerator, load_img
from keras.utils.np_utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, Dropout, Dense, Flatten, BatchNormalization, Conv2D, MaxPooling2D
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras import backend as K
from tensorflow.keras.preprocessing import image
from sklearn.metrics import accuracy_score, classification_report
from pathlib import Path
from PIL import Image
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 8
#       6 import matplotlib.pyplot as plt
#       7 import os, random
# ----> 8 import cv2
#       9 from glob import glob
#      10 import sklearn
#
# ModuleNotFoundError: No module named 'cv2'

# %% [markdown]
#  <h1 style='background:#4686C8; border:0; color:#5CE1E6'><center>PART ONE</center></h1>
#
# <a id="2"></a>
# # **<span style="color:#4686C8;">DIGIT CLASSIFICATION MODEL</span>**
#
# **In this section:**
#
# * Loading Data
# * Splitting The Test Train And Validation Sets
# * Preprocessing The Data
# * Model Building And Training
#
# <a id="3"></a>
# # **<span style="color:#4686C8;">LOADING DATA</span>**
#
# The dataset of images is used for building a suitable model to classify numbers in an image. Data is then specified as features(the image) and labels(the tags).

# %%
#Loading the data 

data = os.listdir(r"../input/digits/Digits" )
data_X = []     
data_y = []  
data_classes = len(data)
for i in range (0,data_classes):
    data_list = os.listdir(r"../input/digits/Digits" +"/"+str(i))
    for j in data_list:
        pic = cv2.imread(r"../input/digits/Digits" +"/"+str(i)+"/"+j)
        pic = cv2.resize(pic,(32,32))
        data_X.append(pic)
        data_y.append(i)

         
if len(data_X) == len(data_y) :
    print("Total Dataponits = ",len(data_X))

# Labels and images
data_X = np.array(data_X)
data_y = np.array(data_y)
# Out:
# Total Dataponits =  10160

# %% [markdown]
# <a id="4"></a>
# # **<span style="color:#4686C8;">SPLITTING DATASET</span>**
#
# Splitting the dataset into test, train and validation sets. Preprocessing for the features (images) into grayscale, enhancing it with histogram equalization and then normalizing. Followed by converting then into a NumPy array. further reshaping the image's array and using data augmentation. Preprocessing for the labels involves one-hot encoding the label classes

# %%
#Spliting the train validation and test sets

train_X, test_X, train_y, test_y = train_test_split(data_X,data_y,test_size=0.05)
train_X, valid_X, train_y, valid_y = train_test_split(train_X,train_y,test_size=0.2)
print("Training Set Shape = ",train_X.shape)
print("Validation Set Shape = ",valid_X.shape)
print("Test Set Shape = ",test_X.shape)
# Out:
# Training Set Shape =  (7721, 32, 32, 3)
# Validation Set Shape =  (1931, 32, 32, 3)
# Test Set Shape =  (508, 32, 32, 3)

# %%
# Preprocessing the images for neuralnet

def Prep(img):
    img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY) #making image grayscale
    img = cv2.equalizeHist(img) #Histogram equalization to enhance contrast
    img = img/255 #normalizing
    return img

train_X = np.array(list(map(Prep, train_X)))
test_X = np.array(list(map(Prep, test_X)))
valid_X= np.array(list(map(Prep, valid_X)))

#Reshaping the images
train_X = train_X.reshape(train_X.shape[0], train_X.shape[1], train_X.shape[2],1)
test_X = test_X.reshape(test_X.shape[0], test_X.shape[1], test_X.shape[2],1)
valid_X = valid_X.reshape(valid_X.shape[0], valid_X.shape[1], valid_X.shape[2],1)

#Augmentation
datagen = ImageDataGenerator(width_shift_range=0.1, height_shift_range=0.1, zoom_range=0.2, shear_range=0.1, rotation_range=10)
datagen.fit(train_X)

# %%
# One hot encoding of the labels

train_y = to_categorical(train_y, data_classes)
test_y = to_categorical(test_y, data_classes)
valid_y = to_categorical(valid_y, data_classes)

# %% [markdown]
# <a id="5"></a>
# # **<span style="color:#4686C8;">MODEL BUILDING</span>**
#
# **For the model, I will build a convolutional neural network.**
# * Initialising the Convolutional network
# * Defining by adding layers
# * Compiling the Convolutional network
# * Train the Convolutional network

# %%
#Creating a Neural Network

model = Sequential()

model.add((Conv2D(60,(5,5),input_shape=(32, 32, 1) ,padding = 'Same' ,activation='relu')))
model.add((Conv2D(60, (5,5),padding="same",activation='relu')))
model.add(MaxPooling2D(pool_size=(2,2)))
#model.add(Dropout(0.25))

model.add((Conv2D(30, (3,3),padding="same", activation='relu')))
model.add((Conv2D(30, (3,3), padding="same", activation='relu')))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))
model.add(Dropout(0.5))

model.add(Flatten())
model.add(Dense(500,activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 60)        1560
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 60)        90060
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 60)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 30)        16230
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 30)        8130
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 30)          0
# _________________________________________________________________
# dropout (Dropout)            (None, 8, 8, 30)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 1920)              0
# _________________________________________________________________
# dense (Dense)                (None, 500)               960500
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                5010
# =================================================================
# Total params: 1,081,490
# Trainable params: 1,081,490
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Compiling the model

optimizer = RMSprop(lr=0.001, rho=0.9, epsilon = 1e-08, decay=0.0)
model.compile(optimizer=optimizer,loss='categorical_crossentropy',metrics=['accuracy'])

#Fit the model

history = model.fit(datagen.flow(train_X, train_y, batch_size=32),
                              epochs = 30, validation_data = (valid_X, valid_y),
                              verbose = 2, steps_per_epoch= 200)
# Out:
# Epoch 1/30
# 200/200 - 65s - loss: 1.1336 - accuracy: 0.6073 - val_loss: 0.0980 - val_accuracy: 0.9694
# Epoch 2/30
# 200/200 - 63s - loss: 0.3168 - accuracy: 0.8981 - val_loss: 0.0624 - val_accuracy: 0.9793
# Epoch 3/30
# 200/200 - 64s - loss: 0.2083 - accuracy: 0.9356 - val_loss: 0.0459 - val_accuracy: 0.9860
# Epoch 4/30
# 200/200 - 64s - loss: 0.1715 - accuracy: 0.9478 - val_loss: 0.0320 - val_accuracy: 0.9881
# Epoch 5/30
# 200/200 - 64s - loss: 0.1517 - accuracy: 0.9561 - val_loss: 0.0276 - val_accuracy: 0.9927
# Epoch 6/30
# 200/200 - 64s - loss: 0.1273 - accuracy: 0.9586 - val_loss: 0.0237 - val_accuracy: 0.9912
# Epoch 7/30
# 200/200 - 64s - loss: 0.1185 - accuracy: 0.9628 - val_loss: 0.0274 - val_accuracy: 0.9912
# Epoch 8/30
# 200/200 - 64s - loss: 0.1215 - accuracy: 0.9624 - val_loss: 0.0253 - val_accuracy: 0.9896
# Epoch 9/30
# 200/200 - 64s - loss: 0.1106 - accuracy: 0.9683 - val_loss: 0.0239 - val_accuracy: 0.9922
# Epoch 10/30
# 200/200 - 63s - loss: 0.1043 - accuracy: 0.9717 - val_loss: 0.0236 - val_accuracy: 0.9938
# Epoch 11/30
# 200/200 - 64s - loss: 0.0965 - accuracy: 0.9727 - val_loss: 0.0178 - val_accuracy: 0.9948
# Epoch 12/30
# 200/200 - 64s - loss: 0.0865 - accuracy: 0.9746 - val_loss: 0.0342 - val_accuracy: 0.9912
# Epoch 13/30
# 200/200 - 64s - loss: 0.0880 - accuracy: 0.9748 - val_loss: 0.0148 - val_accuracy: 0.9933
# Epoch 14/30
# 200/200 - 65s - loss: 0.0841 - accuracy: 0.9749 - val_loss: 0.0136 - val_accuracy: 0.9948
# Epoch 15/30
# 200/200 - 64s - loss: 0.0961 - accuracy: 0.9732 - val_loss: 0.0176 - val_accuracy: 0.9948
# Epoch 16/30
# 200/200 - 64s - loss: 0.0838 - accuracy: 0.9767 - val_loss: 0.0188 - val_accuracy: 0.9943
# Epoch 17/30
# 200/200 - 64s - loss: 0.0801 - accuracy: 0.9756 - val_loss: 0.0190 - val_accuracy: 0.9943
# Epoch 18/30
# 200/200 - 64s - loss: 0.0834 - accuracy: 0.9763 - val_loss: 0.0200 - val_accuracy: 0.9922
# Epoch 19/30
# 200/200 - 64s - loss: 0.0729 - accuracy: 0.9799 - val_loss: 0.0134 - val_accuracy: 0.9948
# Epoch 20/30
# 200/200 - 64s - loss: 0.0812 - accuracy: 0.9782 - val_loss: 0.0180 - val_accuracy: 0.9938
# Epoch 21/30
# 200/200 - 64s - loss: 0.0747 - accuracy: 0.9776 - val_loss: 0.0193 - val_accuracy: 0.9933
# Epoch 22/30
# 200/200 - 64s - loss: 0.0800 - accuracy: 0.9786 - val_loss: 0.0474 - val_accuracy: 0.9876
# Epoch 23/30
# 200/200 - 64s - loss: 0.0714 - accuracy: 0.9795 - val_loss: 0.0173 - val_accuracy: 0.9938
# Epoch 24/30
# 200/200 - 63s - loss: 0.0763 - accuracy: 0.9817 - val_loss: 0.0253 - val_accuracy: 0.9964
# Epoch 25/30
# 200/200 - 64s - loss: 0.0769 - accuracy: 0.9806 - val_loss: 0.0119 - val_accuracy: 0.9969
# Epoch 26/30
# 200/200 - 64s - loss: 0.0777 - accuracy: 0.9790 - val_loss: 0.0177 - val_accuracy: 0.9938
# Epoch 27/30
# 200/200 - 64s - loss: 0.0842 - accuracy: 0.9785 - val_loss: 0.0264 - val_accuracy: 0.9933
# Epoch 28/30
# 200/200 - 63s - loss: 0.0735 - accuracy: 0.9801 - val_loss: 0.0326 - val_accuracy: 0.9927
# Epoch 29/30
# 200/200 - 63s - loss: 0.0701 - accuracy: 0.9818 - val_loss: 0.0269 - val_accuracy: 0.9933
# Epoch 30/30
# 200/200 - 63s - loss: 0.0788 - accuracy: 0.9785 - val_loss: 0.0149 - val_accuracy: 0.9964

# %%
# Testing the model on the test set

score = model.evaluate(test_X, test_y, verbose=0)
print('Test Score = ',score[0])
print('Test Accuracy =', score[1])
# Out:
# Test Score =  0.006115881726145744
# Test Accuracy = 0.9960629940032959

# %% [markdown]
# # <h1 style='background:#4686C8; border:0; color:#5CE1E6'><center>PART TWO</center></h1>
#
# <a id="6"></a>
# # **<span style="color:#4686C8;">READING THE SUDOKU PUZZLE </span>**
#
# **In this section:**
#
# * Read an image from the dataset
# * Preprocess the image

# %%
# Randomly select an image from the dataset 

folder=r"../input/sudoku-box-detection/aug"

a=random.choice(os.listdir(folder))
print(a)
sudoku_a = cv2.imread(folder+'/'+a)
plt.figure()
plt.imshow(sudoku_a)
plt.show()
# Out:
# _49_2910174.jpeg

# %%
#Preprocessing image to be read
sudoku_a = cv2.resize(sudoku_a, (450,450))

# function to greyscale, blur and change the receptive threshold of image
def preprocess(image):
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY) 
    blur = cv2.GaussianBlur(gray, (3,3),6) 
    #blur = cv2.bilateralFilter(gray,9,75,75)
    threshold_img = cv2.adaptiveThreshold(blur,255,1,1,11,2)
    return threshold_img

threshold = preprocess(sudoku_a)

#let's look at what we have got
plt.figure()
plt.imshow(threshold)
plt.show()

# %% [markdown]
# <a id="7"></a>
# # **<span style="color:#4686C8;">DETECTING CONTOUR</span>**
#
# * Detect the biggest contour of the image.
# * Reshaping the outline to get the cropped and well-aligned Sudoku

# %%
# Finding the outline of the sudoku puzzle in the image
contour_1 = sudoku_a.copy()
contour_2 = sudoku_a.copy()
contour, hierarchy = cv2.findContours(threshold,cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)
cv2.drawContours(contour_1, contour,-1,(0,255,0),3)

#let's see what we got
plt.figure()
plt.imshow(contour_1)
plt.show()

# %%
def main_outline(contour):
    biggest = np.array([])
    max_area = 0
    for i in contour:
        area = cv2.contourArea(i)
        if area >50:
            peri = cv2.arcLength(i, True)
            approx = cv2.approxPolyDP(i , 0.02* peri, True)
            if area > max_area and len(approx) ==4:
                biggest = approx
                max_area = area
    return biggest ,max_area

def reframe(points):
    points = points.reshape((4, 2))
    points_new = np.zeros((4,1,2),dtype = np.int32)
    add = points.sum(1)
    points_new[0] = points[np.argmin(add)]
    points_new[3] = points[np.argmax(add)]
    diff = np.diff(points, axis =1)
    points_new[1] = points[np.argmin(diff)]
    points_new[2] = points[np.argmax(diff)]
    return points_new

def splitcells(img):
    rows = np.vsplit(img,9)
    boxes = []
    for r in rows:
        cols = np.hsplit(r,9)
        for box in cols:
            boxes.append(box)
    return boxes


black_img = np.zeros((450,450,3), np.uint8)
biggest, maxArea = main_outline(contour)
if biggest.size != 0:
    biggest = reframe(biggest)
    cv2.drawContours(contour_2,biggest,-1, (0,255,0),10)
    pts1 = np.float32(biggest)
    pts2 = np.float32([[0,0],[450,0],[0,450],[450,450]])
    matrix = cv2.getPerspectiveTransform(pts1,pts2)  
    imagewrap = cv2.warpPerspective(sudoku_a,matrix,(450,450))
    imagewrap =cv2.cvtColor(imagewrap, cv2.COLOR_BGR2GRAY)
    
plt.figure()
plt.imshow(imagewrap)
plt.show()

# %% [markdown]
# The goal of [this](https://www.kaggle.com/macfooty/sudoku-box-detection) dataset is to detect the Sudoku box that has been done.  So yey!
#
# However, some of the images are unfit to use in our model (some are blurr or solved). So to demonstrate solving I have created a toy dataset of one clear picture. I will be using that to run the model and solve the puzzle.

# %%
# Importing puzzle to be solved
puzzle = cv2.imread("../input/su-puzzle/su.jpg")

#let's see what we got
plt.figure()
plt.imshow(puzzle)
plt.show()

# %%
# Resizing puzzle to be solved
puzzle = cv2.resize(puzzle, (450,450))
# Preprocessing Puzzle 
su_puzzle = preprocess(puzzle)

# Finding the outline of the sudoku puzzle in the image
su_contour_1= su_puzzle.copy()
su_contour_2= sudoku_a.copy()
su_contour, hierarchy = cv2.findContours(su_puzzle,cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)
cv2.drawContours(su_contour_1, su_contour,-1,(0,255,0),3)

black_img = np.zeros((450,450,3), np.uint8)
su_biggest, su_maxArea = main_outline(su_contour)
if su_biggest.size != 0:
    su_biggest = reframe(su_biggest)
    cv2.drawContours(su_contour_2,su_biggest,-1, (0,255,0),10)
    su_pts1 = np.float32(su_biggest)
    su_pts2 = np.float32([[0,0],[450,0],[0,450],[450,450]])
    su_matrix = cv2.getPerspectiveTransform(su_pts1,su_pts2)  
    su_imagewrap = cv2.warpPerspective(puzzle,su_matrix,(450,450))
    su_imagewrap =cv2.cvtColor(su_imagewrap, cv2.COLOR_BGR2GRAY)
    
plt.figure()
plt.imshow(su_imagewrap)
plt.show()

# %% [markdown]
# <a id="8"></a>
# # **<span style="color:#4686C8;">SPLITTING THE CELLS AND CLASSIFYING DIGITS</span>**
#
# * Splitting the sudoku box into 81 cells with empty spaces or digits
# * Cropping the cells to avoid misdetection of boundary lines as digits
# * Using the model to classify the digits in the cells such that the empty cells are classified as zero
# * Getting the detected output in the form of an array of 81 digits

# %%
sudoku_cell = splitcells(su_imagewrap)
#Let's have alook at the last cell
plt.figure()
plt.imshow(sudoku_cell[58])
plt.show()

# %%
# The sudoku_cell's output includes the boundaries this could lead to misclassifications by the model 
# I am cropping the cells to avoid that


def CropCell(cells):
    Cells_croped = []
    for image in cells:
        
        img = np.array(image)
        img = img[4:46, 6:46]
        img = Image.fromarray(img)
        Cells_croped.append(img)
        
    return Cells_croped

sudoku_cell_croped= CropCell(sudoku_cell)
#Let's have alook at the last cell
plt.figure()
plt.imshow(sudoku_cell_croped[58])
plt.show()

# %%
def read_cells(cell,model):

    result = []
    for image in cell:
        # preprocess the image as it was in the model 
        img = np.asarray(image)
        img = img[4:img.shape[0] - 4, 4:img.shape[1] -4]
        img = cv2.resize(img, (32, 32))
        img = img / 255
        img = img.reshape(1, 32, 32, 1)
        # getting predictions and setting the values if probabilities are above 65% 
        
        predictions = model.predict(img)
        classIndex = model.predict_classes(img)
        probabilityValue = np.amax(predictions)
        
        if probabilityValue > 0.65:
            result.append(classIndex[0])
        else:
            result.append(0)
    return result

grid = read_cells(sudoku_cell_croped, model)
grid = np.asarray(grid)
# Out:
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %% [markdown]
# # <h1 style='background:#4686C8; border:0; color:#5CE1E6'><center>PART THREE</center></h1>
#
# <a id="9"></a>
# # **<span style="color:#4686C8;">SOLVING THE SUDOKU</span>**
#
# * Reshaping the array into a 9 x 9 matrix
# * Solving the matrix using recursion

# %%
# Reshaping the grid to a 9x9 matrix

grid = np.reshape(grid,(9,9))
grid
# Out:
# array([[3, 8, 0, 9, 0, 0, 2, 0, 5],
#        [0, 0, 0, 0, 0, 8, 7, 3, 0],
#        [0, 6, 0, 3, 0, 0, 9, 8, 0],
#        [0, 0, 0, 0, 0, 3, 5, 0, 1],
#        [9, 1, 0, 5, 0, 7, 0, 2, 3],
#        [7, 0, 3, 1, 0, 0, 0, 0, 0],
#        [0, 3, 5, 0, 0, 1, 0, 9, 0],
#        [0, 7, 4, 6, 0, 0, 0, 0, 0],
#        [8, 0, 1, 0, 0, 2, 0, 6, 7]])

# %%
#For compairing 
plt.figure()
plt.imshow(su_imagewrap)
plt.show()

# %% [markdown]
# Some numbers may be missing as it may be due to the classification probabilities may be below 65%. It could lead to more than one solution.
#
# P.S. Adding an arbitrary number could lead to a puzzle with no solution. Whereas, removing numbers increase the combinations.

# %%
#This function finds the next box to solve 

def next_box(quiz):
    for row in range(9):
        for col in range(9):
            if quiz[row][col] == 0:
                return (row, col)
    return False

#Function to fill in the possible values by evaluating rows collumns and smaller cells

def possible (quiz,row, col, n):
    #global quiz
    for i in range (0,9):
        if quiz[row][i] == n and row != i:
            return False
    for i in range (0,9):
        if quiz[i][col] == n and col != i:
            return False
        
    row0 = (row)//3
    col0 = (col)//3
    for i in range(row0*3, row0*3 + 3):
        for j in range(col0*3, col0*3 + 3):
            if quiz[i][j]==n and (i,j) != (row, col):
                return False
    return True

#Recursion function to loop over untill a valid answer is found. 

def solve(quiz):
    val = next_box(quiz)
    if val is False:
        return True
    else:
        row, col = val
        for n in range(1,10): #n is the possible solution
            if possible(quiz,row, col, n):
                quiz[row][col]=n
                if solve(quiz):
                    return True 
                else:
                    quiz[row][col]=0
        return 
    
def Solved(quiz):
    for row in range(9):
        if row % 3 == 0 and row != 0:
            print("....................")

        for col in range(9):
            if col % 3 == 0 and col != 0:
                print("|", end=" ")

            if col == 8:
                print(quiz[row][col])
            else:
                print(str(quiz[row][col]) + " ", end="")

# %%
solve(grid)
# Out:
# True

# %%
if solve(grid):
    Solved(grid)
else:
    print("Solution don't exist. Model misread digits.")
# Out:
# 3 8 7 | 9 4 6 | 2 1 5
# 5 4 9 | 2 1 8 | 7 3 6
# 1 6 2 | 3 7 5 | 9 8 4
# ....................
# 4 2 6 | 8 9 3 | 5 7 1
# 9 1 8 | 5 6 7 | 6 2 3
# 7 5 3 | 1 2 4 | 8 4 9
# ....................
# 6 3 5 | 7 8 1 | 4 9 2
# 2 7 4 | 6 3 9 | 1 5 8
# 8 9 1 | 4 5 2 | 3 6 7
